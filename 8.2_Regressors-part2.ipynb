# %% [markdown]
# # Entrenamiento de regresores
#
# Objetivo: Para cada hexágono encontrar un valor perceptual.
#
# Cada hexágono tiene:
#
# *  N>=3, donde N es el número mínimo de imágenes
# *  R=10, donde R es la resolución de cada hexágono. Con un área promedio por hexágono de 0.015km2 (15,047.5m2) y largo promedio de cada lado 0.076km
# * Number of regions con estas características: 24220

# %% [markdown]
# ### Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install srai[all]
# !pip install contextily
# !pip install alphashape
# Out:
# Collecting srai[all]
#   Downloading srai-0.7.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from srai[all]) (2.1.4)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (from srai[all]) (0.14.4)
# Requirement already satisfied: shapely in /usr/local/lib/python3.10/dist-packages (from srai[all]) (2.0.5)
# Collecting h3>=4.0.0b1 (from srai[all])
#   Downloading h3-4.0.0b5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from srai[all]) (1.26.4)
# Collecting geoparquet (from srai[all])
#   Downloading geoparquet-0.0.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyfunctional (from srai[all])
#   Downloading pyfunctional-1.5.0-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.8 MB/s eta 0:00:00
# Collecting rtree (from srai[all])
#   Downloading Rtree-1.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: pyarrow>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from srai[all]) (14.0.2)
# Collecting topojson (from srai[all])
#   Downloading topojson-1.9-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from srai[all]) (4.66.5)
# Collecting s2 (from srai[all])
#   Downloading s2-0.1.9-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: typeguard in /usr/local/lib/python3.10/dist-packages (from srai[all]) (4.3.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from srai[all]) (2.32.3)
# Collecting h3ronpy>=0.18.0 (from srai[all])
#   Downloading h3ronpy-0.21.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting osmnx (from srai[all])
#   Downloading osmnx-1.9.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: fiona>=1.8.21 in /usr/local/lib/python3.10/dist-packages (from geopandas->srai[all]) (1.9.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas->srai[all]) (24.1)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from geopandas->srai[all]) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->srai[all]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->srai[all]) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->srai[all]) (2024.1)
# Requirement already satisfied: networkx<3.4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from osmnx->srai[all]) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->srai[all]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->srai[all]) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->srai[all]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->srai[all]) (2024.7.4)
# Collecting dill>=0.2.5 (from pyfunctional->srai[all])
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: tabulate<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from pyfunctional->srai[all]) (0.9.0)
# Collecting s2sphere (from s2->srai[all])
#   Downloading s2sphere-0.2.5-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting overpass (from srai[all])
#   Downloading overpass-0.7.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from srai[all]) (9.4.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from srai[all]) (4.12.3)
# Collecting quackosm>=0.7.1 (from srai[all])
#   Downloading quackosm-0.9.0-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.7/56.7 kB 3.9 MB/s eta 0:00:00
# Collecting pytorch-lightning (from srai[all])
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from srai[all]) (2.3.1+cu121)
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (from srai[all]) (0.17.0)
# Collecting mapclassify (from srai[all])
#   Downloading mapclassify-2.8.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from srai[all]) (3.7.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from srai[all]) (5.15.0)
# Collecting kaleido<=0.2.1 (from srai[all])
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Collecting pymap3d (from srai[all])
#   Downloading pymap3d-3.1.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting haversine (from srai[all])
#   Downloading haversine-2.8.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from srai[all]) (1.13.1)
# Collecting spherical-geometry (from srai[all])
#   Downloading spherical_geometry-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting gtfs-kit (from srai[all])
#   Downloading gtfs_kit-6.1.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from typeguard->srai[all]) (4.12.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas->srai[all]) (24.2.0)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas->srai[all]) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas->srai[all]) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas->srai[all]) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.21->geopandas->srai[all]) (1.16.0)
# Collecting pyarrow>=13.0.0 (from srai[all])
#   Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: duckdb>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from quackosm>=0.7.1->srai[all]) (0.10.3)
# Collecting geoarrow-pyarrow>=0.1.2 (from quackosm>=0.7.1->srai[all])
#   Downloading geoarrow_pyarrow-0.1.2-py3-none-any.whl.metadata (613 bytes)
# Collecting geoarrow-pandas>=0.1.1 (from quackosm>=0.7.1->srai[all])
#   Downloading geoarrow_pandas-0.1.1-py3-none-any.whl.metadata (493 bytes)
# Requirement already satisfied: psutil>=5.6.2 in /usr/local/lib/python3.10/dist-packages (from quackosm>=0.7.1->srai[all]) (5.9.5)
# Requirement already satisfied: pooch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from quackosm>=0.7.1->srai[all]) (1.8.2)
# Collecting pyarrow-ops (from quackosm>=0.7.1->srai[all])
#   Downloading pyarrow_ops-0.0.8.tar.gz (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.4/121.4 kB 9.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: polars>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from quackosm>=0.7.1->srai[all]) (0.20.2)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from quackosm>=0.7.1->srai[all]) (13.7.1)
# Collecting geoarrow-rust-core>=0.2.0 (from quackosm>=0.7.1->srai[all])
#   Downloading geoarrow_rust_core-0.2.0-cp38-abi3-manylinux_2_28_x86_64.whl.metadata (2.6 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->srai[all]) (2.5)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium->srai[all]) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium->srai[all]) (3.1.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium->srai[all]) (2024.6.0)
# Collecting json2html>=1 (from gtfs-kit->srai[all])
#   Downloading json2html-1.3.0.tar.gz (7.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pandas (from srai[all])
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting pycountry>=19 (from gtfs-kit->srai[all])
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting utm>=0.6 (from gtfs-kit->srai[all])
#   Downloading utm-0.7.0.tar.gz (8.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify->srai[all]) (1.3.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->srai[all]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->srai[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->srai[all]) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->srai[all]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->srai[all]) (3.1.2)
# Collecting osm2geojson<0.3.0,>=0.2.5 (from overpass->srai[all])
#   Downloading osm2geojson-0.2.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->srai[all]) (9.0.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning->srai[all]) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->srai[all]) (2024.6.1)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning->srai[all])
#   Downloading torchmetrics-1.4.1-py3-none-any.whl.metadata (20 kB)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning->srai[all])
#   Downloading lightning_utilities-0.11.6-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->srai[all]) (3.15.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->srai[all]) (1.13.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->srai[all])
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->srai[all])
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->srai[all])
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->srai[all])
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->srai[all])
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->srai[all])
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->srai[all])
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->srai[all])
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->srai[all])
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->srai[all])
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->srai[all])
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch->srai[all]) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->srai[all])
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: future>=0.15 in /usr/local/lib/python3.10/dist-packages (from s2sphere->s2->srai[all]) (1.0.0)
# Requirement already satisfied: astropy>=5.0.4 in /usr/local/lib/python3.10/dist-packages (from spherical-geometry->srai[all]) (6.1.2)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.0.4->spherical-geometry->srai[all]) (2.0.1.4)
# Requirement already satisfied: astropy-iers-data>=0.2024.7.1.0.34.3 in /usr/local/lib/python3.10/dist-packages (from astropy>=5.0.4->spherical-geometry->srai[all]) (0.2024.8.5.0.32.23)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->srai[all]) (3.10.2)
# Collecting geoarrow-c (from geoarrow-pyarrow>=0.1.2->quackosm>=0.7.1->srai[all])
#   Downloading geoarrow_c-0.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (400 bytes)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from geoarrow-pyarrow>=0.1.2->quackosm>=0.7.1->srai[all]) (0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium->srai[all]) (2.1.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning->srai[all]) (71.0.4)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.6.0->quackosm>=0.7.1->srai[all]) (4.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->quackosm>=0.7.1->srai[all]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.0.0->quackosm>=0.7.1->srai[all]) (2.16.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify->srai[all]) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->mapclassify->srai[all]) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->srai[all]) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->srai[all]) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->srai[all]) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->srai[all]) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->srai[all]) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->srai[all]) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->srai[all]) (4.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->quackosm>=0.7.1->srai[all]) (0.1.2)
# Downloading h3-4.0.0b5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 48.0 MB/s eta 0:00:00
# Downloading h3ronpy-0.21.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 16.8 MB/s eta 0:00:00
# Downloading geoparquet-0.0.3-py3-none-any.whl (4.3 kB)
# Downloading osmnx-1.9.4-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 9.0 MB/s eta 0:00:00
# Downloading pyfunctional-1.5.0-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.2 MB/s eta 0:00:00
# Downloading Rtree-1.3.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (543 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.2/543.2 kB 39.9 MB/s eta 0:00:00
# Downloading s2-0.1.9-py2.py3-none-any.whl (4.1 kB)
# Downloading srai-0.7.5-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.2/118.2 kB 9.2 MB/s eta 0:00:00
# Downloading topojson-1.9-py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 6.8 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.8 MB/s eta 0:00:00
# Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 26.6 MB/s eta 0:00:00
# Downloading quackosm-0.9.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 kB 5.6 MB/s eta 0:00:00
# Downloading pyarrow-17.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (39.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 60.7 MB/s eta 0:00:00
# Downloading gtfs_kit-6.1.1-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.2/63.2 kB 4.9 MB/s eta 0:00:00
# Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 115.4 MB/s eta 0:00:00
# Downloading haversine-2.8.1-py2.py3-none-any.whl (7.7 kB)
# Downloading mapclassify-2.8.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 4.9 MB/s eta 0:00:00
# Downloading overpass-0.7.2-py3-none-any.whl (13 kB)
# Downloading pymap3d-3.1.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.2 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 45.7 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading s2sphere-0.2.5-py2.py3-none-any.whl (23 kB)
# Downloading spherical_geometry-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 9.9 MB/s eta 0:00:00
# Downloading geoarrow_pandas-0.1.1-py3-none-any.whl (6.2 kB)
# Downloading geoarrow_pyarrow-0.1.2-py3-none-any.whl (26 kB)
# Downloading geoarrow_rust_core-0.2.0-cp38-abi3-manylinux_2_28_x86_64.whl (15.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 55.3 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.6-py3-none-any.whl (26 kB)
# Downloading pycountry-24.6.1-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 122.4 MB/s eta 0:00:00
# Downloading torchmetrics-1.4.1-py3-none-any.whl (866 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.2/866.2 kB 43.8 MB/s eta 0:00:00
# Downloading geoarrow_c-0.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 84.0 MB/s eta 0:00:00
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Building wheels for collected packages: json2html, osm2geojson, utm, pyarrow-ops
#   Building wheel for json2html (setup.py) ... done
#   Created wheel for json2html: filename=json2html-1.3.0-py3-none-any.whl size=7591 sha256=cb96229d84acf08dbffd37d6d951ff4b8db51113e7b10cfbebb8d53bc525d414
#   Stored in directory: /root/.cache/pip/wheels/e0/d8/b3/6f83a04ab0ec00e691de794d108286bb0f8bcdf4ade19afb57
#   Building wheel for osm2geojson (setup.py) ... done
#   Created wheel for osm2geojson: filename=osm2geojson-0.2.5-py3-none-any.whl size=13951 sha256=a4d525f74514c432244e51b5cf93c505a8de27d7033ccd69bc4d80d6f8a80180
#   Stored in directory: /root/.cache/pip/wheels/44/9d/4c/a859e0f56957a67bf06c3a5a14899205c3b1864471fcc3c2cc
#   Building wheel for utm (setup.py) ... done
#   Created wheel for utm: filename=utm-0.7.0-py3-none-any.whl size=6085 sha256=b33a969cc650b42fb52f40ef2460ea45584dc8b030e484f46f481a3ffe29502d
#   Stored in directory: /root/.cache/pip/wheels/2f/a1/c8/543df0e8f5e824c3e92a432e32deb9cd89ae686095ee8cfcbe
#   Building wheel for pyarrow-ops (pyproject.toml) ... done
#   Created wheel for pyarrow-ops: filename=pyarrow_ops-0.0.8-cp310-cp310-linux_x86_64.whl size=381716 sha256=313868f76e5682f7d9ea4fee55f102eb742f65736445f336c99caabe8fb59e46
#   Stored in directory: /root/.cache/pip/wheels/1f/bf/fd/160fc3192cf18af67a6e4b360747ba167a46ea1f15f83c73cb
# Successfully built json2html osm2geojson utm pyarrow-ops
# Installing collected packages: utm, kaleido, json2html, h3, geoparquet, s2sphere, rtree, pymap3d, pycountry, pyarrow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lightning-utilities, haversine, geoarrow-rust-core, geoarrow-c, dill, topojson, s2, pyfunctional, pyarrow-ops, pandas, osm2geojson, nvidia-cusparse-cu12, nvidia-cudnn-cu12, h3ronpy, geoarrow-pyarrow, spherical-geometry, overpass, nvidia-cusolver-cu12, mapclassify, geoarrow-pandas, quackosm, osmnx, gtfs-kit, torchmetrics, srai, pytorch-lightning
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 2.2.2 which is incompatible.
# cudf-cu12 24.4.1 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 17.0.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.1.4, but you have pandas 2.2.2 which is incompatible.
# ibis-framework 8.0.0 requires pyarrow<16,>=2, but you have pyarrow 17.0.0 which is incompatible.
# Successfully installed dill-0.3.8 geoarrow-c-0.1.2 geoarrow-pandas-0.1.1 geoarrow-pyarrow-0.1.2 geoarrow-rust-core-0.2.0 geoparquet-0.0.3 gtfs-kit-6.1.1 h3-4.0.0b5 h3ronpy-0.21.0 haversine-2.8.1 json2html-1.3.0 kaleido-0.2.1 lightning-utilities-0.11.6 mapclassify-2.8.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 osm2geojson-0.2.5 osmnx-1.9.4 overpass-0.7.2 pandas-2.2.2 pyarrow-17.0.0 pyarrow-ops-0.0.8 pycountry-24.6.1 pyfunctional-1.5.0 pymap3d-3.1.0 pytorch-lightning-2.4.0 quackosm-0.9.0 rtree-1.3.0 s2-0.1.9 s2sphere-0.2.5 spherical-geometry-1.3.2 srai-0.7.5 topojson-1.9 torchmetrics-1.4.1 utm-0.7.0
# Collecting contextily
#   Downloading contextily-1.6.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: geopy in /usr/local/lib/python3.10/dist-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from contextily) (3.7.1)
# Collecting mercantile (from contextily)
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from contextily) (9.4.0)
# Collecting rasterio (from contextily)
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from contextily) (2.32.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from contextily) (1.4.2)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from contextily) (2024.6.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.10/dist-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->contextily) (2.8.2)
# Requirement already satisfied: click>=3.0 in /usr/local/lib/python3.10/dist-packages (from mercantile->contextily) (8.1.7)
# Collecting affine (from rasterio->contextily)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (24.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (2024.7.4)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (0.7.2)
# Collecting snuggs>=1.4.1 (from rasterio->contextily)
#   Downloading snuggs-1.4.7-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio->contextily) (71.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->contextily) (2.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)
# Downloading contextily-1.6.1-py3-none-any.whl (17 kB)
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 102.6 MB/s eta 0:00:00
# Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Installing collected packages: snuggs, mercantile, affine, rasterio, contextily
# Successfully installed affine-2.4.0 contextily-1.6.1 mercantile-1.2.1 rasterio-1.3.10 snuggs-1.4.7
# Collecting alphashape
#   Downloading alphashape-1.3.1-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.10/dist-packages (from alphashape) (8.1.7)
# Collecting click-log>=0.3.2 (from alphashape)
#   Downloading click_log-0.4.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: shapely>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from alphashape) (2.0.5)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from alphashape) (1.26.4)
# Collecting trimesh>=3.9.8 (from alphashape)
#   Downloading trimesh-4.4.6-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.10/dist-packages (from alphashape) (3.3)
# Requirement already satisfied: rtree>=0.9.7 in /usr/local/lib/python3.10/dist-packages (from alphashape) (1.3.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from alphashape) (1.13.1)
# Downloading alphashape-1.3.1-py2.py3-none-any.whl (13 kB)
# Downloading click_log-0.4.0-py2.py3-none-any.whl (4.3 kB)
# Downloading trimesh-4.4.6-py3-none-any.whl (696 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 696.2/696.2 kB 25.7 MB/s eta 0:00:00
# Installing collected packages: trimesh, click-log, alphashape
# Successfully installed alphashape-1.3.1 click-log-0.4.0 trimesh-4.4.6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import folium
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Point
import zipfile
import srai
import os
from PIL import Image
import glob
import contextily as ctx
import alphashape


from sklearn.metrics import mean_squared_error, median_absolute_error,r2_score, mean_absolute_percentage_error
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
import scipy.stats
import pickle
from sklearn.svm import SVR
from sklearn.model_selection import cross_validate
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.neural_network import MLPRegressor


from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#To create embeddings
from srai.loaders import OSMOnlineLoader, OSMWayLoader, OSMPbfLoader
from srai.regionalizers import geocode_to_region_gdf, S2Regionalizer
from srai.plotting import plot_regions, plot_numeric_data
from srai.embedders import CountEmbedder, ContextualCountEmbedder,Hex2VecEmbedder, Highway2VecEmbedder
from srai.joiners import IntersectionJoiner
from srai.loaders.osm_loaders.filters import HEX2VEC_FILTER
from srai.neighbourhoods.h3_neighbourhood import H3Neighbourhood
from srai.regionalizers import H3Regionalizer, geocode_to_region_gdf

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Create dataset and training/testing sets

# %% [markdown]
# ### Df embeddings

# %%
df_embeddings = pd.read_csv('/content/drive/MyDrive/UC-TESIS/data/embeddings/h3_embeddings_150_75_100.csv')
df_embeddings
# Out:
#              region_id         0         1         2         3         4  \
# 0      8ab2c54614b7fff -0.023930  0.040677 -0.017497 -0.275375  0.103468
# 1      8ab2c5409c37fff -0.356221  0.336155  0.056644 -0.032715  0.185949
# 2      8ab2c5735c27fff  0.511298  0.475341  0.060442  0.396583 -0.291473
# 3      8ab2c5470d37fff -0.154229 -0.212532 -0.277868  0.359974 -0.432614
# 4      8ab2c51982d7fff  0.117171 -0.137542  0.248391  0.000995 -0.488907
# ...                ...       ...       ...       ...       ...       ...
# 24215  8ab2c5440607fff  0.129073 -0.313071 -0.266625  0.206505  0.424100
# 24216  8ab2c5735ba7fff -0.023930  0.040677 -0.017497 -0.275375  0.103468
# 24217  8ab2c519132ffff -0.023930  0.040677 -0.017497 -0.275375  0.103468
# 24218  8ab2c5573517fff -0.023930  0.040677 -0.017497 -0.275375  0.103468
# 24219  8ab2c5476c8ffff -0.003901 -0.167946  0.270491 -0.096673 -0.162327
#
#               5         6         7         8  ...        90        91  \
# 0      0.078189 -0.061404  0.082823  0.071790  ...  0.180155 -0.046677
# 1     -0.196175 -0.233436  0.125683  0.293554  ... -0.012782  0.278413
# 2      0.012991 -0.526473  0.214151  0.395182  ...  0.071864 -0.055179
# 3     -0.131339 -0.035649 -0.234396  0.266802  ...  0.030813 -0.076295
# 4     -0.224059  0.048757 -0.305915  0.187887  ... -0.703700 -0.091194
# ...         ...       ...       ...       ...  ...       ...       ...
# 24215 -0.071679 -0.106600 -0.243351 -0.110525  ...  0.437696  0.314795
# 24216  0.078189 -0.061404  0.082823  0.071790  ...  0.180155 -0.046677
# 24217  0.078189 -0.061404  0.082823  0.071790  ...  0.180155 -0.046677
# 24218  0.078189 -0.061404  0.082823  0.071790  ...  0.180155 -0.046677
# 24219 -0.090249  0.020707 -0.134936 -0.290442  ... -0.016138 -0.261915
#
#              92        93        94        95        96        97        98  \
# 0      0.126445 -0.061428 -0.006454 -0.030310  0.056697 -0.153097  0.123646
# 1      0.040773  0.042589 -0.320704 -0.143026 -0.161286 -0.083865 -0.558367
# 2      0.182469  0.402972 -0.274875 -0.136615 -0.433164 -0.104150  0.073335
# 3      0.212762 -0.210441 -0.170993  0.012732 -0.051932  0.190558  0.100510
# 4      0.196549 -0.125396 -0.249640 -0.063369  0.138847  0.637275 -0.073419
# ...         ...       ...       ...       ...       ...       ...       ...
# 24215  0.128654 -0.177794  0.288626 -0.032735  0.041986  0.082394  0.089014
# 24216  0.126445 -0.061428 -0.006454 -0.030310  0.056697 -0.153097  0.123646
# 24217  0.126445 -0.061428 -0.006454 -0.030310  0.056697 -0.153097  0.123646
# 24218  0.126445 -0.061428 -0.006454 -0.030310  0.056697 -0.153097  0.123646
# 24219 -0.324950  0.235275 -0.120623 -0.091219  0.205162 -0.209587 -0.185340
#
#              99
# 0     -0.004010
# 1     -0.020263
# 2      0.634614
# 3     -0.181921
# 4      0.112756
# ...         ...
# 24215 -0.192874
# 24216 -0.004010
# 24217 -0.004010
# 24218 -0.004010
# 24219 -0.253886
#
# [24220 rows x 101 columns]

# %%
df_embeddings['region_id'].nunique()
# Out:
# 24220

# %%
df_embeddings = df_embeddings.set_index('region_id')
df_embeddings
# Out:
#                         0         1         2         3         4         5  \
# region_id
# 8ab2c54614b7fff -0.023930  0.040677 -0.017497 -0.275375  0.103468  0.078189
# 8ab2c5409c37fff -0.356221  0.336155  0.056644 -0.032715  0.185949 -0.196175
# 8ab2c5735c27fff  0.511298  0.475341  0.060442  0.396583 -0.291473  0.012991
# 8ab2c5470d37fff -0.154229 -0.212532 -0.277868  0.359974 -0.432614 -0.131339
# 8ab2c51982d7fff  0.117171 -0.137542  0.248391  0.000995 -0.488907 -0.224059
# ...                   ...       ...       ...       ...       ...       ...
# 8ab2c5440607fff  0.129073 -0.313071 -0.266625  0.206505  0.424100 -0.071679
# 8ab2c5735ba7fff -0.023930  0.040677 -0.017497 -0.275375  0.103468  0.078189
# 8ab2c519132ffff -0.023930  0.040677 -0.017497 -0.275375  0.103468  0.078189
# 8ab2c5573517fff -0.023930  0.040677 -0.017497 -0.275375  0.103468  0.078189
# 8ab2c5476c8ffff -0.003901 -0.167946  0.270491 -0.096673 -0.162327 -0.090249
#
#                         6         7         8         9  ...        90  \
# region_id                                                ...
# 8ab2c54614b7fff -0.061404  0.082823  0.071790  0.071382  ...  0.180155
# 8ab2c5409c37fff -0.233436  0.125683  0.293554  0.491351  ... -0.012782
# 8ab2c5735c27fff -0.526473  0.214151  0.395182  0.211956  ...  0.071864
# 8ab2c5470d37fff -0.035649 -0.234396  0.266802  0.241064  ...  0.030813
# 8ab2c51982d7fff  0.048757 -0.305915  0.187887 -0.228582  ... -0.703700
# ...                   ...       ...       ...       ...  ...       ...
# 8ab2c5440607fff -0.106600 -0.243351 -0.110525  0.429839  ...  0.437696
# 8ab2c5735ba7fff -0.061404  0.082823  0.071790  0.071382  ...  0.180155
# 8ab2c519132ffff -0.061404  0.082823  0.071790  0.071382  ...  0.180155
# 8ab2c5573517fff -0.061404  0.082823  0.071790  0.071382  ...  0.180155
# 8ab2c5476c8ffff  0.020707 -0.134936 -0.290442 -0.046935  ... -0.016138
#
#                        91        92        93        94        95        96  \
# region_id
# 8ab2c54614b7fff -0.046677  0.126445 -0.061428 -0.006454 -0.030310  0.056697
# 8ab2c5409c37fff  0.278413  0.040773  0.042589 -0.320704 -0.143026 -0.161286
# 8ab2c5735c27fff -0.055179  0.182469  0.402972 -0.274875 -0.136615 -0.433164
# 8ab2c5470d37fff -0.076295  0.212762 -0.210441 -0.170993  0.012732 -0.051932
# 8ab2c51982d7fff -0.091194  0.196549 -0.125396 -0.249640 -0.063369  0.138847
# ...                   ...       ...       ...       ...       ...       ...
# 8ab2c5440607fff  0.314795  0.128654 -0.177794  0.288626 -0.032735  0.041986
# 8ab2c5735ba7fff -0.046677  0.126445 -0.061428 -0.006454 -0.030310  0.056697
# 8ab2c519132ffff -0.046677  0.126445 -0.061428 -0.006454 -0.030310  0.056697
# 8ab2c5573517fff -0.046677  0.126445 -0.061428 -0.006454 -0.030310  0.056697
# 8ab2c5476c8ffff -0.261915 -0.324950  0.235275 -0.120623 -0.091219  0.205162
#
#                        97        98        99
# region_id
# 8ab2c54614b7fff -0.153097  0.123646 -0.004010
# 8ab2c5409c37fff -0.083865 -0.558367 -0.020263
# 8ab2c5735c27fff -0.104150  0.073335  0.634614
# 8ab2c5470d37fff  0.190558  0.100510 -0.181921
# 8ab2c51982d7fff  0.637275 -0.073419  0.112756
# ...                   ...       ...       ...
# 8ab2c5440607fff  0.082394  0.089014 -0.192874
# 8ab2c5735ba7fff -0.153097  0.123646 -0.004010
# 8ab2c519132ffff -0.153097  0.123646 -0.004010
# 8ab2c5573517fff -0.153097  0.123646 -0.004010
# 8ab2c5476c8ffff -0.209587 -0.185340 -0.253886
#
# [24220 rows x 100 columns]

# %% [markdown]
# ### Df variables perceptuales

# %%
df = pd.read_csv('/content/drive/MyDrive/UC-TESIS/data/vars_perceptuales_santiago.csv')
df
# Out:
#                                       latlong  beautiful    boring  \
# 0               -33.323944,-70.51263428391168  -0.306948  1.565049
# 1                      -33.323944,-70.5127291  -0.421388  0.309495
# 2               -33.323944,-70.51298714285714   0.116505  0.164284
# 3               -33.323944,-70.51343609999999  -0.159113 -0.500987
# 4               -33.323944,-70.51379769565217  -1.226162  1.176751
# ...                                       ...        ...       ...
# 121346  -33.67884090851735,-70.68059514195582  -1.318599  2.201657
# 121347  -33.67884090851735,-70.69912023659306   0.827014  1.129426
# 121348  -33.67884090851735,-70.70653027444796   0.975725  0.838188
# 121349   -33.67884090851735,-70.7176453312303  -0.629273  0.780489
# 121350  -33.67884090851735,-70.72505536908517   0.484484  0.801168
#
#         depressing    lively      safe   wealthy        lat        lon
# 0         0.572029 -1.137733 -0.120456 -0.561887 -33.323944 -70.512634
# 1         0.368965 -0.098733 -0.103042 -0.162294 -33.323944 -70.512729
# 2        -0.110312  0.063860  0.391172  0.226372 -33.323944 -70.512987
# 3        -0.213503  0.635165  0.300856  0.453708 -33.323944 -70.513436
# 4         1.462015 -0.842954 -0.946355 -0.936168 -33.323944 -70.513798
# ...            ...       ...       ...       ...        ...        ...
# 121346    1.673377 -2.265229 -1.677807 -2.014101 -33.678841 -70.680595
# 121347   -0.431715 -1.053424  0.438107  0.078089 -33.678841 -70.699120
# 121348   -0.583064 -0.515637  0.957951  0.547197 -33.678841 -70.706530
# 121349    0.881986 -1.363918 -1.328026 -1.726176 -33.678841 -70.717645
# 121350    0.013836 -1.306747 -0.702592 -0.575198 -33.678841 -70.725055
#
# [121351 rows x 9 columns]

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat))
gdf = gdf.set_crs(epsg=4326)
gdf_rm= gdf.copy().drop(columns=['lat', 'lon', 'latlong'])
gdf_rm
# Out:
#         beautiful    boring  depressing    lively      safe   wealthy  \
# 0       -0.306948  1.565049    0.572029 -1.137733 -0.120456 -0.561887
# 1       -0.421388  0.309495    0.368965 -0.098733 -0.103042 -0.162294
# 2        0.116505  0.164284   -0.110312  0.063860  0.391172  0.226372
# 3       -0.159113 -0.500987   -0.213503  0.635165  0.300856  0.453708
# 4       -1.226162  1.176751    1.462015 -0.842954 -0.946355 -0.936168
# ...           ...       ...         ...       ...       ...       ...
# 121346  -1.318599  2.201657    1.673377 -2.265229 -1.677807 -2.014101
# 121347   0.827014  1.129426   -0.431715 -1.053424  0.438107  0.078089
# 121348   0.975725  0.838188   -0.583064 -0.515637  0.957951  0.547197
# 121349  -0.629273  0.780489    0.881986 -1.363918 -1.328026 -1.726176
# 121350   0.484484  0.801168    0.013836 -1.306747 -0.702592 -0.575198
#
#                            geometry
# 0       POINT (-70.51263 -33.32394)
# 1       POINT (-70.51273 -33.32394)
# 2       POINT (-70.51299 -33.32394)
# 3       POINT (-70.51344 -33.32394)
# 4       POINT (-70.51380 -33.32394)
# ...                             ...
# 121346  POINT (-70.68060 -33.67884)
# 121347  POINT (-70.69912 -33.67884)
# 121348  POINT (-70.70653 -33.67884)
# 121349  POINT (-70.71765 -33.67884)
# 121350  POINT (-70.72506 -33.67884)
#
# [121351 rows x 7 columns]

# %% [markdown]
# Create region_id column

# %%
# Extraer los puntos de la columna 'geometry'
points = list(gdf_rm.geometry)
points = np.array([[point.x, point.y] for point in gdf_rm.geometry])
# Calcular el alpha shape
alpha = 100
alpha_shape = alphashape.alphashape(points, alpha)

# Crear un nuevo GeoDataFrame con el alpha shape
gdf_alpha_shape = gpd.GeoDataFrame(geometry=[alpha_shape])
gdf_alpha_shape['region_id'] = "Santiago Metropolitan Region, Chile"
gdf_alpha_shape = gdf_alpha_shape.set_crs(epsg=4326)
study_area2 = gdf_alpha_shape
study_area2
# Out:
#                                             geometry  \
# 0  MULTIPOLYGON (((-70.76705 -33.67659, -70.76581...
#
#                              region_id
# 0  Santiago Metropolitan Region, Chile

# %%
regionalizer = H3Regionalizer(resolution=10, buffer=True)
regions_gdf_rm_10 = regionalizer.transform(study_area2)
regions_gdf_rm_10_no_index= regions_gdf_rm_10.reset_index()
regions_gdf_rm_10_no_index
# Out:
#              region_id                                           geometry
# 0      8ab2c546d727fff  POLYGON ((-70.60364 -33.54995, -70.60427 -33.5...
# 1      8ab2c55046cffff  POLYGON ((-70.82357 -33.35232, -70.82421 -33.3...
# 2      8ab2c5181d8ffff  POLYGON ((-70.50459 -33.35980, -70.50522 -33.3...
# 3      8ab2c5571537fff  POLYGON ((-70.70536 -33.39716, -70.70599 -33.3...
# 4      8ab2c5706cd7fff  POLYGON ((-70.57196 -33.62285, -70.57259 -33.6...
# ...                ...                                                ...
# 87105  8ab2c550ea17fff  POLYGON ((-70.79517 -33.38967, -70.79580 -33.3...
# 87106  8ab2c547072ffff  POLYGON ((-70.73160 -33.53311, -70.73223 -33.5...
# 87107  8ab2c519c9a7fff  POLYGON ((-70.54077 -33.37709, -70.54140 -33.3...
# 87108  8ab2c57a4217fff  POLYGON ((-70.67016 -33.64302, -70.67079 -33.6...
# 87109  8ab2c50b24b7fff  POLYGON ((-70.60665 -33.46935, -70.60728 -33.4...
#
# [87110 rows x 2 columns]

# %% [markdown]
# Add region_id colum with regionalizer function.

# %%
#Contiene solo las filas donde ambos gdf  se intersectan
df_perceptual = gpd.sjoin(gdf_rm, regions_gdf_rm_10_no_index, how="inner", predicate="intersects")
df_perceptual.drop(columns=['index_right'], inplace=True)
df_perceptual
# Out:
#         beautiful    boring  depressing    lively      safe   wealthy  \
# 0       -0.306948  1.565049    0.572029 -1.137733 -0.120456 -0.561887
# 1       -0.421388  0.309495    0.368965 -0.098733 -0.103042 -0.162294
# 2        0.116505  0.164284   -0.110312  0.063860  0.391172  0.226372
# 3       -0.159113 -0.500987   -0.213503  0.635165  0.300856  0.453708
# 4       -1.226162  1.176751    1.462015 -0.842954 -0.946355 -0.936168
# ...           ...       ...         ...       ...       ...       ...
# 121346  -1.318599  2.201657    1.673377 -2.265229 -1.677807 -2.014101
# 121347   0.827014  1.129426   -0.431715 -1.053424  0.438107  0.078089
# 121348   0.975725  0.838188   -0.583064 -0.515637  0.957951  0.547197
# 121349  -0.629273  0.780489    0.881986 -1.363918 -1.328026 -1.726176
# 121350   0.484484  0.801168    0.013836 -1.306747 -0.702592 -0.575198
#
#                            geometry        region_id
# 0       POINT (-70.51263 -33.32394)  8ab2c51a2297fff
# 1       POINT (-70.51273 -33.32394)  8ab2c51a2297fff
# 2       POINT (-70.51299 -33.32394)  8ab2c51a274ffff
# 3       POINT (-70.51344 -33.32394)  8ab2c51a274ffff
# 4       POINT (-70.51380 -33.32394)  8ab2c51a274ffff
# ...                             ...              ...
# 121346  POINT (-70.68060 -33.67884)  8ab2c57a30affff
# 121347  POINT (-70.69912 -33.67884)  8ab2c57849affff
# 121348  POINT (-70.70653 -33.67884)  8ab2c5784d37fff
# 121349  POINT (-70.71765 -33.67884)  8ab2c57b1067fff
# 121350  POINT (-70.72506 -33.67884)  8ab2c57b10a7fff
#
# [121345 rows x 8 columns]

# %% [markdown]
# ### Create final dataset antes de split

# %% [markdown]
# * ***Dataset full*** con regiones múltiples y con más de 1 feature por hexágono

# %%
#only matching rows from both df
dataset_full = pd.merge(df_perceptual, df_embeddings, on='region_id')
dataset_full = dataset_full.set_index('region_id').drop(columns=['geometry'])
dataset_full
# Out:
#                  beautiful    boring  depressing    lively      safe  \
# region_id
# 8ab2c51a274ffff   0.116505  0.164284   -0.110312  0.063860  0.391172
# 8ab2c51a274ffff  -0.159113 -0.500987   -0.213503  0.635165  0.300856
# 8ab2c51a274ffff  -1.226162  1.176751    1.462015 -0.842954 -0.946355
# 8ab2c51a274ffff  -0.308952  0.491572    0.351956 -0.205486  0.098004
# 8ab2c51a274ffff  -0.255187  0.108916    0.208224  0.178949  0.217683
# ...                    ...       ...         ...       ...       ...
# 8ab2c54dd80ffff   0.077252  0.637953    0.144422 -0.589375 -0.117685
# 8ab2c54dd80ffff   0.688408  0.694112   -0.407948 -0.622452  0.357219
# 8ab2c57a268ffff  -0.065934  2.345176    0.678399 -2.201416 -0.623765
# 8ab2c57a268ffff   0.411270  1.080804    0.115137 -1.929492 -1.131603
# 8ab2c57a268ffff   0.635286  1.352087    0.014607 -1.945503 -0.760037
#
#                   wealthy         0         1         2         3  ...  \
# region_id                                                          ...
# 8ab2c51a274ffff  0.226372 -0.023930  0.040677 -0.017497 -0.275375  ...
# 8ab2c51a274ffff  0.453708 -0.023930  0.040677 -0.017497 -0.275375  ...
# 8ab2c51a274ffff -0.936168 -0.023930  0.040677 -0.017497 -0.275375  ...
# 8ab2c51a274ffff -0.171525 -0.023930  0.040677 -0.017497 -0.275375  ...
# 8ab2c51a274ffff  0.072019 -0.023930  0.040677 -0.017497 -0.275375  ...
# ...                   ...       ...       ...       ...       ...  ...
# 8ab2c54dd80ffff -0.098696 -0.300282 -0.230503  0.195256 -0.364696  ...
# 8ab2c54dd80ffff  0.302788 -0.300282 -0.230503  0.195256 -0.364696  ...
# 8ab2c57a268ffff -0.908452 -0.095155  0.081839  0.058075  0.198763  ...
# 8ab2c57a268ffff -1.081190 -0.095155  0.081839  0.058075  0.198763  ...
# 8ab2c57a268ffff -0.688474 -0.095155  0.081839  0.058075  0.198763  ...
#
#                        90        91        92        93        94        95  \
# region_id
# 8ab2c51a274ffff  0.180155 -0.046677  0.126445 -0.061428 -0.006454 -0.030310
# 8ab2c51a274ffff  0.180155 -0.046677  0.126445 -0.061428 -0.006454 -0.030310
# 8ab2c51a274ffff  0.180155 -0.046677  0.126445 -0.061428 -0.006454 -0.030310
# 8ab2c51a274ffff  0.180155 -0.046677  0.126445 -0.061428 -0.006454 -0.030310
# 8ab2c51a274ffff  0.180155 -0.046677  0.126445 -0.061428 -0.006454 -0.030310
# ...                   ...       ...       ...       ...       ...       ...
# 8ab2c54dd80ffff  0.160869 -0.016424 -0.036420  0.376509 -0.010768 -0.141948
# 8ab2c54dd80ffff  0.160869 -0.016424 -0.036420  0.376509 -0.010768 -0.141948
# 8ab2c57a268ffff -0.160243 -0.125825 -0.070056  0.252882  0.131426 -0.226724
# 8ab2c57a268ffff -0.160243 -0.125825 -0.070056  0.252882  0.131426 -0.226724
# 8ab2c57a268ffff -0.160243 -0.125825 -0.070056  0.252882  0.131426 -0.226724
#
#                        96        97        98        99
# region_id
# 8ab2c51a274ffff  0.056697 -0.153097  0.123646 -0.004010
# 8ab2c51a274ffff  0.056697 -0.153097  0.123646 -0.004010
# 8ab2c51a274ffff  0.056697 -0.153097  0.123646 -0.004010
# 8ab2c51a274ffff  0.056697 -0.153097  0.123646 -0.004010
# 8ab2c51a274ffff  0.056697 -0.153097  0.123646 -0.004010
# ...                   ...       ...       ...       ...
# 8ab2c54dd80ffff -0.526136  0.079622  0.009509  0.082694
# 8ab2c54dd80ffff -0.526136  0.079622  0.009509  0.082694
# 8ab2c57a268ffff -0.199880  0.119445 -0.031587  0.105807
# 8ab2c57a268ffff -0.199880  0.119445 -0.031587  0.105807
# 8ab2c57a268ffff -0.199880  0.119445 -0.031587  0.105807
#
# [83728 rows x 106 columns]

# %% [markdown]
# regiones únicas = 24220 --> dataset.region_id.nunique()

# %% [markdown]
# **Problema**: Para cada región (hexágono) tenemos distintas características (beautiful,	boring,	depressing,	lively,	safe	y wealthy) dentro de cada región. ¿Cuál es la mejor manera de ponderar esas características y representar mejor cada región? -->  media aritmética, la geométrica, el máximo, moda, mediana, otro?

# %%
dataset_full.index
# Out:
# Index(['8ab2c51a274ffff', '8ab2c51a274ffff', '8ab2c51a274ffff',
#        '8ab2c51a274ffff', '8ab2c51a274ffff', '8ab2c51a274ffff',
#        '8ab2c51a275ffff', '8ab2c51a275ffff', '8ab2c51a275ffff',
#        '8ab2c51a278ffff',
#        ...
#        '8ab2c57b1d6ffff', '8ab2c57a14d7fff', '8ab2c57a14d7fff',
#        '8ab2c57a14d7fff', '8ab2c54dd80ffff', '8ab2c54dd80ffff',
#        '8ab2c54dd80ffff', '8ab2c57a268ffff', '8ab2c57a268ffff',
#        '8ab2c57a268ffff'],
#       dtype='object', name='region_id', length=83728)

# %%
dataset_full.loc['8ab2c5012c4ffff']
# Out:
#                  beautiful    boring  depressing    lively      safe  \
# region_id
# 8ab2c5012c4ffff   2.422687 -1.120363   -2.311725  1.064008  1.668255
# 8ab2c5012c4ffff   1.339041 -2.964601   -1.852630  2.743750  1.533512
# 8ab2c5012c4ffff   1.383741 -3.306867   -1.947520  3.033949  1.619152
# 8ab2c5012c4ffff   0.975627  0.692605   -0.647154 -0.738592  0.483502
#
#                   wealthy         0         1         2         3  ...  \
# region_id                                                          ...
# 8ab2c5012c4ffff  1.819982  0.061735  0.028381 -0.014441  0.140128  ...
# 8ab2c5012c4ffff  1.962026  0.061735  0.028381 -0.014441  0.140128  ...
# 8ab2c5012c4ffff  2.060544  0.061735  0.028381 -0.014441  0.140128  ...
# 8ab2c5012c4ffff  0.307371  0.061735  0.028381 -0.014441  0.140128  ...
#
#                        90        91       92        93        94        95  \
# region_id
# 8ab2c5012c4ffff  0.050715 -0.271304 -0.21377  0.192833  0.213708  0.039599
# 8ab2c5012c4ffff  0.050715 -0.271304 -0.21377  0.192833  0.213708  0.039599
# 8ab2c5012c4ffff  0.050715 -0.271304 -0.21377  0.192833  0.213708  0.039599
# 8ab2c5012c4ffff  0.050715 -0.271304 -0.21377  0.192833  0.213708  0.039599
#
#                        96        97        98        99
# region_id
# 8ab2c5012c4ffff -0.188866  0.170294  0.169785  0.159016
# 8ab2c5012c4ffff -0.188866  0.170294  0.169785  0.159016
# 8ab2c5012c4ffff -0.188866  0.170294  0.169785  0.159016
# 8ab2c5012c4ffff -0.188866  0.170294  0.169785  0.159016
#
# [4 rows x 106 columns]

# %% [markdown]
# Media aritmética

# %%
df_means = dataset_full.groupby('region_id').mean()
df_means
# Out:
#                  beautiful    boring  depressing    lively      safe  \
# region_id
# 8ab2c5012c4ffff   1.530274 -1.674806   -1.689757  1.525779  1.326105
# 8ab2c5080057fff   1.797793 -0.473614   -1.603372  0.481697  1.303100
# 8ab2c5080087fff   0.617557  1.008862   -0.127893 -1.063960 -0.006197
# 8ab2c508009ffff   0.344537  0.689234   -0.113139 -0.690042 -0.006416
# 8ab2c50800f7fff   0.658131 -0.016540   -0.538743 -0.102794  0.375745
# ...                    ...       ...         ...       ...       ...
# 8ab2c5cdeca7fff  -0.422076  1.432125    0.556406 -0.505823  0.275188
# 8ab2c5cdecaffff  -0.301907  0.642069    0.367796 -0.402620 -0.067361
# 8ab2c5cdecd7fff  -0.047693  0.280894    0.017444 -0.186770 -0.057487
# 8ab2c5cdecdffff  -0.932705  1.460426    1.053305 -1.076747 -0.633851
# 8ab2c5cded4ffff  -0.155561  0.795472    0.266673 -0.135532  0.328444
#
#                   wealthy         0         1         2         3  ...  \
# region_id                                                          ...
# 8ab2c5012c4ffff  1.537481  0.061735  0.028381 -0.014441  0.140128  ...
# 8ab2c5080057fff  1.463700 -0.009823 -0.065363  0.021479 -0.529560  ...
# 8ab2c5080087fff -0.005126 -0.049334  0.016889 -0.024865 -0.654026  ...
# 8ab2c508009ffff -0.023423 -0.023930  0.040677 -0.017497 -0.275375  ...
# 8ab2c50800f7fff  0.415797 -0.023930  0.040677 -0.017497 -0.275375  ...
# ...                   ...       ...       ...       ...       ...  ...
# 8ab2c5cdeca7fff -0.190039 -0.195331 -0.210522 -0.279355  0.339834  ...
# 8ab2c5cdecaffff -0.244828 -0.152469 -0.207537 -0.275766  0.355418  ...
# 8ab2c5cdecd7fff  0.011591 -0.154229 -0.212532 -0.277868  0.359974  ...
# 8ab2c5cdecdffff -0.852946 -0.152469 -0.207537 -0.275766  0.355418  ...
# 8ab2c5cded4ffff  0.158066 -0.204525 -0.215049 -0.210992  0.318929  ...
#
#                        90        91        92        93        94        95  \
# region_id
# 8ab2c5012c4ffff  0.050715 -0.271304 -0.213770  0.192833  0.213708  0.039599
# 8ab2c5080057fff  0.026409 -0.246902  0.014540 -0.198926 -0.076141 -0.011190
# 8ab2c5080087fff -0.141553 -0.123275  0.003810 -0.035499 -0.403222  0.020489
# 8ab2c508009ffff  0.180155 -0.046677  0.126445 -0.061428 -0.006454 -0.030310
# 8ab2c50800f7fff  0.180155 -0.046677  0.126445 -0.061428 -0.006454 -0.030310
# ...                   ...       ...       ...       ...       ...       ...
# 8ab2c5cdeca7fff -0.006257 -0.070476  0.206203 -0.153168 -0.100565 -0.045583
# 8ab2c5cdecaffff  0.027344 -0.072804  0.207733 -0.203336 -0.168068  0.012886
# 8ab2c5cdecd7fff  0.030813 -0.076295  0.212762 -0.210441 -0.170993  0.012732
# 8ab2c5cdecdffff  0.027344 -0.072804  0.207733 -0.203336 -0.168068  0.012886
# 8ab2c5cded4ffff  0.000909 -0.053991  0.167591 -0.074408  0.040151 -0.149315
#
#                        96        97        98        99
# region_id
# 8ab2c5012c4ffff -0.188866  0.170294  0.169785  0.159016
# 8ab2c5080057fff  0.102937  0.077663  0.060189 -0.084835
# 8ab2c5080087fff -0.083732  0.241804  0.027533 -0.298355
# 8ab2c508009ffff  0.056697 -0.153097  0.123646 -0.004010
# 8ab2c50800f7fff  0.056697 -0.153097  0.123646 -0.004010
# ...                   ...       ...       ...       ...
# 8ab2c5cdeca7fff -0.066746  0.180717  0.064394 -0.221057
# 8ab2c5cdecaffff -0.051808  0.189225  0.097021 -0.178744
# 8ab2c5cdecd7fff -0.051932  0.190558  0.100510 -0.181921
# 8ab2c5cdecdffff -0.051808  0.189225  0.097021 -0.178744
# 8ab2c5cded4ffff -0.143942  0.099945  0.036558 -0.210406
#
# [24220 rows x 106 columns]

# %%
df_means.to_csv('/content/drive/MyDrive/UC-TESIS/data/df_means.csv', index=False)

# %% [markdown]
# Media geométrica --> problema? valores nan

# %%
df_geometric_means = dataset_full.groupby('region_id').apply(lambda x: scipy.stats.gmean(x, axis=0))
df_geometric_means
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_stats_py.py:208: RuntimeWarning: invalid value encountered in log
#   log_a = np.log(a)
# region_id
# 8ab2c5012c4ffff    [1.4466298704361675, nan, nan, nan, 1.18962190...
# 8ab2c5080057fff    [1.7164934053267011, nan, nan, nan, 1.28358348...
# 8ab2c5080087fff    [0.5735789661957594, 0.9077705082996049, nan, ...
# 8ab2c508009ffff    [nan, 0.4741728846110169, nan, nan, nan, nan, ...
# 8ab2c50800f7fff    [nan, nan, nan, nan, nan, nan, nan, 0.04067694...
#                                          ...
# 8ab2c5cdeca7fff    [nan, 1.3652880381323635, 0.542970119811581, n...
# 8ab2c5cdecaffff    [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 8ab2c5cdecd7fff    [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 8ab2c5cdecdffff    [nan, 1.4199495536775772, 1.0392234245913927, ...
# 8ab2c5cded4ffff    [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# Length: 24220, dtype: object

# %% [markdown]
# Mediana

# %%
df_medians = dataset_full.groupby('region_id').median()
df_medians
# Out:
#                  beautiful    boring  depressing    lively      safe  \
# region_id
# 8ab2c5012c4ffff   1.361391 -2.042482   -1.900075  1.903879  1.576332
# 8ab2c5080057fff   1.604606 -0.781635   -1.509878  0.690671  1.329464
# 8ab2c5080087fff   0.534498  1.203662   -0.124734 -0.988998 -0.178066
# 8ab2c508009ffff   0.523684  0.534084   -0.243849 -0.727690 -0.063302
# 8ab2c50800f7fff   0.338217 -0.086866   -0.254180 -0.074327  0.160953
# ...                    ...       ...         ...       ...       ...
# 8ab2c5cdeca7fff  -0.426769  1.631752    0.593024 -0.516723  0.275822
# 8ab2c5cdecaffff  -0.180813  0.702974    0.187430 -0.467125 -0.044658
# 8ab2c5cdecd7fff  -0.537953  0.905214    0.774207 -0.618593 -0.771503
# 8ab2c5cdecdffff  -0.974256  1.550554    1.053681 -1.071634 -0.626345
# 8ab2c5cded4ffff  -0.306910  1.112744    0.613995 -0.190341  0.141685
#
#                   wealthy         0         1         2         3  ...  \
# region_id                                                          ...
# 8ab2c5012c4ffff  1.891004  0.061735  0.028381 -0.014441  0.140128  ...
# 8ab2c5080057fff  1.497841 -0.009823 -0.065363  0.021479 -0.529560  ...
# 8ab2c5080087fff -0.009102 -0.049334  0.016889 -0.024865 -0.654026  ...
# 8ab2c508009ffff -0.097517 -0.023930  0.040677 -0.017497 -0.275375  ...
# 8ab2c50800f7fff  0.149841 -0.023930  0.040677 -0.017497 -0.275375  ...
# ...                   ...       ...       ...       ...       ...  ...
# 8ab2c5cdeca7fff -0.118063 -0.195331 -0.210522 -0.279355  0.339834  ...
# 8ab2c5cdecaffff -0.363213 -0.152469 -0.207537 -0.275766  0.355418  ...
# 8ab2c5cdecd7fff -0.753049 -0.154229 -0.212532 -0.277868  0.359974  ...
# 8ab2c5cdecdffff -0.882865 -0.152469 -0.207537 -0.275766  0.355418  ...
# 8ab2c5cded4ffff -0.119250 -0.204525 -0.215049 -0.210992  0.318929  ...
#
#                        90        91        92        93        94        95  \
# region_id
# 8ab2c5012c4ffff  0.050715 -0.271304 -0.213770  0.192833  0.213708  0.039599
# 8ab2c5080057fff  0.026409 -0.246902  0.014540 -0.198926 -0.076141 -0.011190
# 8ab2c5080087fff -0.141553 -0.123275  0.003810 -0.035499 -0.403222  0.020489
# 8ab2c508009ffff  0.180155 -0.046677  0.126445 -0.061428 -0.006454 -0.030310
# 8ab2c50800f7fff  0.180155 -0.046677  0.126445 -0.061428 -0.006454 -0.030310
# ...                   ...       ...       ...       ...       ...       ...
# 8ab2c5cdeca7fff -0.006257 -0.070476  0.206203 -0.153168 -0.100565 -0.045583
# 8ab2c5cdecaffff  0.027344 -0.072804  0.207733 -0.203336 -0.168068  0.012886
# 8ab2c5cdecd7fff  0.030813 -0.076295  0.212762 -0.210441 -0.170993  0.012732
# 8ab2c5cdecdffff  0.027344 -0.072804  0.207733 -0.203336 -0.168068  0.012886
# 8ab2c5cded4ffff  0.000909 -0.053991  0.167591 -0.074408  0.040151 -0.149315
#
#                        96        97        98        99
# region_id
# 8ab2c5012c4ffff -0.188866  0.170294  0.169785  0.159016
# 8ab2c5080057fff  0.102937  0.077663  0.060189 -0.084835
# 8ab2c5080087fff -0.083732  0.241804  0.027533 -0.298355
# 8ab2c508009ffff  0.056697 -0.153097  0.123646 -0.004010
# 8ab2c50800f7fff  0.056697 -0.153097  0.123646 -0.004010
# ...                   ...       ...       ...       ...
# 8ab2c5cdeca7fff -0.066746  0.180717  0.064394 -0.221057
# 8ab2c5cdecaffff -0.051808  0.189225  0.097021 -0.178744
# 8ab2c5cdecd7fff -0.051932  0.190558  0.100510 -0.181921
# 8ab2c5cdecdffff -0.051808  0.189225  0.097021 -0.178744
# 8ab2c5cded4ffff -0.143942  0.099945  0.036558 -0.210406
#
# [24220 rows x 106 columns]

# %%
df_medians.to_csv('/content/drive/MyDrive/UC-TESIS/data/df_medians.csv', index=False)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Split
#
# 80% for training
#
# 20% for testing
#
# *  Matriz X: embeddings OSM hex2vec
# *  Vector objetivo y: variables perceptuales de las imágenes. Probar vector objetivo por separado: beautiful y boring
# ```
# # hex2vec columns OSM
# X = df_means.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
# # Perceptual columns
# y = df_means[['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy']]
#
# ```

# %% [markdown]
# ## 1.Random forest

# %%
#X_train_1, X_test_1, y_train_1, y_test_1 = train_test_split(X, y, test_size=0.2, random_state=25)
#y_pred_1 = rf_model_df_means_1.predict(X_test_1)

# %% [markdown]
# Probar vector objetivo por separado
#   - beautiful
#   - boring
#
# 10 variaciones del modelo cada uno entrenado y evalado en diferentes random subsets

# %% [markdown]
# **cross_val_score**
#
# 'neg_mean_squared_error':  especifica que la métrica  para evaluar el modelo en cada fold es el MSE negativo. La razón? cross_val_score espera una función de puntuación donde las puntuaciones más altas son mejores. Como el MSE es una medida de error (valores más bajos son mejores), se niega para alinearlo con la convención.
#
# El signo menos (-) del cross_val_score invierte los valores para obtener el MSE positivo. cv_scores_mse contendrá una matriz de valores MSE para cada fold.

# %% [markdown]
# versión rápida

# %%
# Dataset
# hex2vec columns OSM
X = df_means.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_means[['beautiful']]  #y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
model = RandomForestRegressor(n_estimators=100, random_state=25)

#model.fit(X_train, y_train.values.ravel())
#model.score(X_test, y_test)
# Out:
# RandomForestRegressor(random_state=25)
# 0.06384447039093544

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mape_scorer = make_scorer(mean_absolute_percentage_error, greater_is_better=False)

# %% [markdown]
# ### 1.1 Random forest con df media, y= beautiful

# %%
# %%time
# Dataset
# hex2vec columns OSM
X = df_means.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_means[['beautiful']]  #y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
model = RandomForestRegressor(n_estimators=100, random_state=25)

# Define the scoring metrics
scoring = {
    'mse': make_scorer(mean_squared_error),
    'r2': make_scorer(r2_score),
    'mape': mape_scorer
}

# Perform cross-validation
cv_results = cross_validate(model, X_train, y_train.values.ravel(), cv=5, scoring=scoring, return_train_score=True)

# Access training scores
train_mse = cv_results['train_mse']
train_r2 = cv_results['train_r2']
train_mape = cv_results['train_mape']

# Access testing scores
test_mse = cv_results['test_mse']
test_r2 = cv_results['test_r2']
test_mape = cv_results['test_mape']

# Dado que greater_is_better=False, los scores son negativos, así que multiplicamos por -1
#cv_results = -cv_results

# Print the results
print("Training MSE:", train_mse.mean())
print("Training R2:", train_r2.mean())
print("Training MAPE:", train_mape.mean())
print("--------------------")
print("Testing MSE:", test_mse.mean())
print("Testing R2:", test_r2.mean())
print("Testing MAPE:", test_mape.mean())
# Out:
# comenzó?
# Training MSE: 0.2990755039418754 +/- 0.0015920921575398133
# Training R2: 0.477019513335118 +/- 0.002867505622326969
# Training MAPE: -136.4722317010928 +/- 7.598235807914923
# --------------------
# Testing MSE: 0.5383165136282135 +/- 0.0031010682261656693
# Testing R2: 0.05854525266550774 +/- 0.005942037954608193
# Testing MAPE: -222.94139053122944 +/- 36.490511369565446
# CPU times: user 10min 47s, sys: 527 ms, total: 10min 48s
# Wall time: 10min 53s

# %% [markdown]
# media beautiful, matriz x todo menos vector objetivo

# %%
# %%time
# Dataset
# hex2vec columns OSM
X = df_means.drop(['beautiful'], axis=1)
y = df_means[['beautiful']]  #y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
model = RandomForestRegressor(n_estimators=100, random_state=25)

# Define the scoring metrics
scoring = {
    'mse': make_scorer(mean_squared_error),
    'r2': make_scorer(r2_score),
    'mape': mape_scorer
}

# Perform cross-validation
cv_results = cross_validate(model, X_train, y_train.values.ravel(), cv=5, scoring=scoring, return_train_score=True)

# Access training scores
train_mse = cv_results['train_mse']
train_r2 = cv_results['train_r2']
train_mape = cv_results['train_mape']

# Access testing scores
test_mse = cv_results['test_mse']
test_r2 = cv_results['test_r2']
test_mape = cv_results['test_mape']

# Dado que greater_is_better=False, los scores son negativos, así que multiplicamos por -1
#cv_results = -cv_results

# Print the results
print("Training MSE:", train_mse.mean())
print("Training R2:", train_r2.mean())
print("Training MAPE:", train_mape.mean())
print("--------------------")
print("Testing MSE:", test_mse.mean())
print("Testing R2:", test_r2.mean())
print("Testing MAPE:", test_mape.mean())
# Out:
# Training MSE: 0.0006461406486378944
# Training R2: 0.9988701166054783
# Training MAPE: -19.80243618573134
# --------------------
# Testing MSE: 0.004582040811147992
# Testing R2: 0.9919862309687117
# Testing MAPE: -53.445674918233046
# CPU times: user 7min 32s, sys: 330 ms, total: 7min 32s
# Wall time: 7min 30s

# %% [markdown]
# ### 1.2 Random forest con df media, y= boring

# %%
# %%time

# Dataset
# hex2vec columns OSM
X = df_means.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_means[['boring']]  #y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
model = RandomForestRegressor(n_estimators=100, random_state=25)

# Define the scoring metrics
scoring = {
    'mse': make_scorer(mean_squared_error),
    'r2': make_scorer(r2_score),
    'mape': mape_scorer
}

# Perform cross-validation
cv_results = cross_validate(model, X_train, y_train.values.ravel(), cv=5, scoring=scoring, return_train_score=True)

# Access training scores
train_mse = cv_results['train_mse']
train_r2 = cv_results['train_r2']
train_mape = cv_results['train_mape']

# Access testing scores
test_mse = cv_results['test_mse']
test_r2 = cv_results['test_r2']
test_mape = cv_results['test_mape']

# Dado que greater_is_better=False, los scores son negativos, así que multiplicamos por -1
#cv_results = -cv_results

# Print the results
print("Training MSE:", train_mse.mean())
print("Training R2:", train_r2.mean())
print("Training MAPE:", train_mape.mean())
print("--------------------")
print("Testing MSE:", test_mse.mean())
print("Testing R2:", test_r2.mean())
print("Testing MAPE:", test_mape.mean())
# Out:
# Training MSE: 0.22749716527303826
# Training R2: 0.5995714113218684
# Training MAPE: -168.9882096975019
# --------------------
# Testing MSE: 0.44503807207197943
# Testing R2: 0.21614548591504973
# Testing MAPE: -274.608294140321
# CPU times: user 8min 11s, sys: 360 ms, total: 8min 11s
# Wall time: 8min 9s

# %% [markdown]
# media boring, matriz x todo menos vector objetivo

# %%
# %%time

# hex2vec columns OSM
X = df_means.drop(['boring'], axis=1)
y = df_means[['boring']]  #y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
model = RandomForestRegressor(n_estimators=100, random_state=25)

# Define the scoring metrics
scoring = {
    'mse': make_scorer(mean_squared_error),
    'r2': make_scorer(r2_score),
    'mape': mape_scorer
}

# Perform cross-validation
cv_results = cross_validate(model, X_train, y_train.values.ravel(), cv=5, scoring=scoring, return_train_score=True)

# Access training scores
train_mse = cv_results['train_mse']
train_r2 = cv_results['train_r2']
train_mape = cv_results['train_mape']

# Access testing scores
test_mse = cv_results['test_mse']
test_r2 = cv_results['test_r2']
test_mape = cv_results['test_mape']

# Dado que greater_is_better=False, los scores son negativos, así que multiplicamos por -1
#cv_results = -cv_results

# Print the results
print("Training MSE:", train_mse.mean())
print("Training R2:", train_r2.mean())
print("Training MAPE:", train_mape.mean())
print("--------------------")
print("Testing MSE:", test_mse.mean())
print("Testing R2:", test_r2.mean())
print("Testing MAPE:", test_mape.mean())
# Out:
# Training MSE: 0.0017129007928285904
# Training R2: 0.9969849595100347
# Training MAPE: -31.764050107570245
# --------------------
# Testing MSE: 0.01198772059847137
# Testing R2: 0.9788861267159821
# Testing MAPE: -81.81927489303503
# CPU times: user 7min 40s, sys: 347 ms, total: 7min 40s
# Wall time: 7min 38s

# %% [markdown]
# ### 1.3 Random forest con df mediana, y=beautiful

# %%
# %%time
# Dataset
# hex2vec columns OSM
X = df_medians.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_medians[['beautiful']]  #y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
model = RandomForestRegressor(n_estimators=100, random_state=25)

# Define the scoring metrics
scoring = {
    'mse': make_scorer(mean_squared_error),
    'r2': make_scorer(r2_score),
    'mape': mape_scorer
}

# Perform cross-validation
cv_results = cross_validate(model, X_train, y_train.values.ravel(), cv=5, scoring=scoring, return_train_score=True)

# Access training scores
train_mse = cv_results['train_mse']
train_r2 = cv_results['train_r2']
train_mape = cv_results['train_mape']

# Access testing scores
test_mse = cv_results['test_mse']
test_r2 = cv_results['test_r2']
test_mape = cv_results['test_mape']

# Dado que greater_is_better=False, los scores son negativos, así que multiplicamos por -1
#cv_results = -cv_results

# Print the results
print("Training MSE:", train_mse.mean())
print("Training R2:", train_r2.mean())
print("Training MAPE:", train_mape.mean())
print("--------------------")
print("Testing MSE:", test_mse.mean())
print("Testing R2:", test_r2.mean())
print("Testing MAPE:", test_mape.mean())
# Out:
# Training MSE: 0.3350880487219855
# Training R2: 0.47693380538351315
# Training MAPE: -154.85022124423978
# --------------------
# Testing MSE: 0.6094812959010738
# Testing R2: 0.04846288436441706
# Testing MAPE: -221.40668141788927
# CPU times: user 7min 40s, sys: 336 ms, total: 7min 40s
# Wall time: 7min 38s

# %% [markdown]
# mediana beautiful, matriz x todo menos vector objetivo

# %%
# %%time
# Dataset
# hex2vec columns OSM
X = df_medians.drop(['beautiful'], axis=1)
y = df_medians[['beautiful']]  #y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
model = RandomForestRegressor(n_estimators=100, random_state=25)

# Define the scoring metrics
scoring = {
    'mse': make_scorer(mean_squared_error),
    'r2': make_scorer(r2_score),
    'mape': mape_scorer
}

# Perform cross-validation
cv_results = cross_validate(model, X_train, y_train.values.ravel(), cv=5, scoring=scoring, return_train_score=True)

# Access training scores
train_mse = cv_results['train_mse']
train_r2 = cv_results['train_r2']
train_mape = cv_results['train_mape']

# Access testing scores
test_mse = cv_results['test_mse']
test_r2 = cv_results['test_r2']
test_mape = cv_results['test_mape']

# Dado que greater_is_better=False, los scores son negativos, así que multiplicamos por -1
#cv_results = -cv_results

# Print the results
print("Training MSE:", train_mse.mean())
print("Training R2:", train_r2.mean())
print("Training MAPE:", train_mape.mean())
print("--------------------")
print("Testing MSE:", test_mse.mean())
print("Testing R2:", test_r2.mean())
print("Testing MAPE:", test_mape.mean())
# Out:
# Training MSE: 0.0028303437078941035
# Training R2: 0.9955818963946633
# Training MAPE: -41.250841896543065
# --------------------
# Testing MSE: 0.02013260221135966
# Testing R2: 0.9685652584864073
# Testing MAPE: -112.94245068107068
# CPU times: user 7min 57s, sys: 368 ms, total: 7min 57s
# Wall time: 7min 55s

# %% [markdown]
# ### 1.4 Random forest con df mediana, y=boring

# %%
# %%time
# Dataset
# hex2vec columns OSM
X = df_medians.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_medians[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
model = RandomForestRegressor(n_estimators=100, random_state=25)

# Define the scoring metrics
scoring = {
    'mse': make_scorer(mean_squared_error),
    'r2': make_scorer(r2_score),
    'mape': mape_scorer
}

# Perform cross-validation
cv_results = cross_validate(model, X_train, y_train.values.ravel(), cv=5, scoring=scoring, return_train_score=True)

# Access training scores
train_mse = cv_results['train_mse']
train_r2 = cv_results['train_r2']
train_mape = -cv_results['train_mape']

# Access testing scores
test_mse = cv_results['test_mse']
test_r2 = cv_results['test_r2']
test_mape = -cv_results['test_mape']

# Dado que greater_is_better=False, los scores son negativos, así que multiplicamos por -1
#cv_results = -cv_results

# Print the results
print("Training MSE:", train_mse.mean())
print("Training R2:", train_r2.mean())
print("Training MAPE:", train_mape.mean())
print("--------------------")
print("Testing MSE:", test_mse.mean())
print("Testing R2:", test_r2.mean())
print("Testing MAPE:", test_mape.mean())
# Out:
# Training MSE: 0.27004648874564585
# Training R2: 0.5872991278545594
# Training MAPE: 195.4184330499715
# --------------------
# Testing MSE: 0.5310282134574151
# Testing R2: 0.1880893514830976
# Testing MAPE: 325.4297824875017
# CPU times: user 8min 15s, sys: 354 ms, total: 8min 16s
# Wall time: 8min 14s

# %% [markdown]
# mediana boring, matriz x todo menos vector objetivo

# %%
# %%time
# Dataset
# hex2vec columns OSM
X = df_medians.drop(['boring'], axis=1)
y = df_medians[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)
model = RandomForestRegressor(n_estimators=100, random_state=25)

# Define the scoring metrics
scoring = {
    'mse': make_scorer(mean_squared_error),
    'r2': make_scorer(r2_score),
    'mape': mape_scorer
}

# Perform cross-validation
cv_results = cross_validate(model, X_train, y_train.values.ravel(), cv=5, scoring=scoring, return_train_score=True)

# Access training scores
train_mse = cv_results['train_mse']
train_r2 = cv_results['train_r2']
train_mape = -cv_results['train_mape']

# Access testing scores
test_mse = cv_results['test_mse']
test_r2 = cv_results['test_r2']
test_mape = -cv_results['test_mape']

# Dado que greater_is_better=False, los scores son negativos, así que multiplicamos por -1
#cv_results = -cv_results

# Print the results
print("Training MSE:", train_mse.mean())
print("Training R2:", train_r2.mean())
print("Training MAPE:", train_mape.mean())
print("--------------------")
print("Testing MSE:", test_mse.mean())
print("Testing R2:", test_r2.mean())
print("Testing MAPE:", test_mape.mean())
# Out:
# Training MSE: 0.007808303651528628
# Training R2: 0.9880670310154482
# Training MAPE: 64.58186172513442
# --------------------
# Testing MSE: 0.05595059779769775
# Testing R2: 0.9144157383334257
# Testing MAPE: 166.1330836945861
# CPU times: user 8min 3s, sys: 258 ms, total: 8min 4s
# Wall time: 8min 2s

# %% [markdown]
# ## Métricas
#
# * **R²**  mide qué tan bien el modelo se ajusta a los datos observados, indica la
# proporción de la variabilidad en la variable dependiente que es explicada por el modelo.
#   - R² de 1 indica un ajuste perfecto, donde el modelo explica toda la variabilidad de los datos.
#   - R² de 0 indica que el modelo no explica ninguna variabilidad y es tan bueno como simplemente predecir la media de la variable dependiente.
#   - R² negativos indican que el modelo se ajusta peor a los datos que una línea horizontal (la media).
#
# * **MAPE** promedio de los porcentajes de error absoluto entre las predicciones y los valores reales. MAPE más bajo indica un mejor ajuste del modelo a los datos. Ej.MAPE del 10% significa que, en promedio, las predicciones del modelo se desvían un 10% de los valores reales.
#
# `MAPE = (1/n) * Σ(|(Valor Real - Valor Predicho)| / |Valor Real|) * 100%`
#
#     n es el número de observaciones.
#
#     Σ indica la suma de los errores porcentuales absolutos.
#
# * **MSE** mide la precisión de las predicciones especialmente cuando se desea penalizar más los errores grandes. Se calcula como el promedio de los cuadrados de las diferencias entre las predicciones y los valores reales.
#
# `MSE = (1/n) * Σ(Valor Real - Valor Predicho)²`
#
#     n es el número de observaciones.
#
#     Σ indica la suma de los cuadrados de las diferencias

# %% [markdown]
# ---
#
#
#
# ---

# %% [markdown]
# ## 2.SVR

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_percentage_error
from sklearn.model_selection import RandomizedSearchCV

# %%
X = df_means.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_means[['beautiful']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# %% [markdown]
# ### 2.1 SVR con df media, y= beautiful

# %% [markdown]
# SVR Median - beautiful

# %%
# %%time
X = df_means.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_means[['beautiful']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Simplified grid search parameters
param_grid_simplified = {
    'kernel': ['linear'],
    'C': [1],
    'gamma': ['auto'],
    'epsilon': [0.1]
}

# Initialize the SVR model
svr = SVR()

print("Grid search")
# Grid search with cross-validation
#grid_search_scaled = GridSearchCV(svr, param_grid_simplified, cv=3, scoring='r2')
#grid_search_scaled.fit(X_train_scaled, y_train.values.ravel())

random_search = RandomizedSearchCV(svr, param_distributions=param_grid_simplified, n_iter=10, cv=3, scoring='r2', random_state=25)
random_search.fit(X_train_scaled, y_train.values.ravel())
# Out:
# Grid search
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# CPU times: user 4min 46s, sys: 176 ms, total: 4min 46s
# Wall time: 4min 45s
# RandomizedSearchCV(cv=3, estimator=SVR(),
#                    param_distributions={'C': [1], 'epsilon': [0.1],
#                                         'gamma': ['auto'],
#                                         'kernel': ['linear']},
#                    random_state=25, scoring='r2')

# %%
# Best model
#best_model_scaled = grid_search_scaled.best_estimator_
best_model_scaled = random_search.best_estimator_

print("making predictions")
# Making predictions
y_train_pred_scaled = best_model_scaled.predict(X_train_scaled)
y_test_pred_scaled = best_model_scaled.predict(X_test_scaled)

print("Calculating metrics")
# Calculating metrics
r2_train_scaled = r2_score(y_train, y_train_pred_scaled)
mse_train_scaled = mean_squared_error(y_train, y_train_pred_scaled)
mape_train_scaled = mean_absolute_percentage_error(y_train, y_train_pred_scaled)

r2_test_scaled = r2_score(y_test, y_test_pred_scaled)
mse_test_scaled = mean_squared_error(y_test, y_test_pred_scaled)
mape_test_scaled = mean_absolute_percentage_error(y_test, y_test_pred_scaled)

# Storing metrics in a DataFrame
metrics_scaled = {
    'R2 (Train)': [r2_train_scaled],
    'MSE (Train)': [mse_train_scaled],
    'MAPE (Train)': [mape_train_scaled],
    'R2 (Test)': [r2_test_scaled],
    'MSE (Test)': [mse_test_scaled],
    'MAPE (Test)': [mape_test_scaled],
    'Best Parameters': [random_search.best_params_]
}

metrics_df_scaled = pd.DataFrame(metrics_scaled)
metrics_df_scaled

#import ace_tools as tools; tools.display_dataframe_to_user(name="SVR Model Metrics with Standard Scaling", dataframe=metrics_df_scaled)
# Out:
# making predictions
# Calculating metrics

# %%
metrics_df_scaled
# Out:
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)  \
# 0    0.091946     0.519291      2.253059   0.082098     0.51296     2.070631
#
#                                      Best Parameters
# 0  {'kernel': 'linear', 'gamma': 'auto', 'epsilon...

# %% [markdown]
# media beautiful, matriz x todo menos vector objetivo

# %%
# %%time
X = df_means.drop(['beautiful'], axis=1)
y = df_means[['beautiful']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Simplified grid search parameters
param_grid_simplified = {
    'kernel': ['linear'],
    'C': [1],
    'gamma': ['auto'],
    'epsilon': [0.1]
}

# Initialize the SVR model
svr = SVR()

print("Grid search")
# Grid search with cross-validation
#grid_search_scaled = GridSearchCV(svr, param_grid_simplified, cv=3, scoring='r2')
#grid_search_scaled.fit(X_train_scaled, y_train.values.ravel())

random_search = RandomizedSearchCV(svr, param_distributions=param_grid_simplified, n_iter=10, cv=3, scoring='r2', random_state=25)
random_search.fit(X_train_scaled, y_train.values.ravel())

# Best model
#best_model_scaled = grid_search_scaled.best_estimator_
best_model_scaled = random_search.best_estimator_

print("making predictions")
# Making predictions
y_train_pred_scaled = best_model_scaled.predict(X_train_scaled)
y_test_pred_scaled = best_model_scaled.predict(X_test_scaled)

print("Calculating metrics")
# Calculating metrics
r2_train_scaled = r2_score(y_train, y_train_pred_scaled)
mse_train_scaled = mean_squared_error(y_train, y_train_pred_scaled)
mape_train_scaled = mean_absolute_percentage_error(y_train, y_train_pred_scaled)

r2_test_scaled = r2_score(y_test, y_test_pred_scaled)
mse_test_scaled = mean_squared_error(y_test, y_test_pred_scaled)
mape_test_scaled = mean_absolute_percentage_error(y_test, y_test_pred_scaled)

# Storing metrics in a DataFrame
metrics_scaled = {
    'R2 (Train)': [r2_train_scaled],
    'MSE (Train)': [mse_train_scaled],
    'MAPE (Train)': [mape_train_scaled],
    'R2 (Test)': [r2_test_scaled],
    'MSE (Test)': [mse_test_scaled],
    'MAPE (Test)': [mape_test_scaled],
    'Best Parameters': [random_search.best_params_]
}

metrics_df_scaled = pd.DataFrame(metrics_scaled)
metrics_df_scaled

#import ace_tools as tools; tools.display_dataframe_to_user(name="SVR Model Metrics with Standard Scaling", dataframe=metrics_df_scaled)
# Out:
# Grid search
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# making predictions
# Calculating metrics
# CPU times: user 2min, sys: 57.3 ms, total: 2min 1s
# Wall time: 2min
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)  \
# 0    0.994286     0.003268      0.457351   0.993872    0.003424     0.409809
#
#                                      Best Parameters
# 0  {'kernel': 'linear', 'gamma': 'auto', 'epsilon...

# %% [markdown]
# ### 2.2 SVR con df media, y= boring

# %%
# %%time
X = df_means.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Simplified grid search parameters
param_grid_simplified = {
    'kernel': ['linear'],
    'C': [1],
    'gamma': ['auto'],
    'epsilon': [0.1]
}

# Initialize the SVR model
svr = SVR()

print("Grid search")
# Grid search with cross-validation
#grid_search_scaled = GridSearchCV(svr, param_grid_simplified, cv=3, scoring='r2')
#grid_search_scaled.fit(X_train_scaled, y_train.values.ravel())

random_search = RandomizedSearchCV(svr, param_distributions=param_grid_simplified, n_iter=10, cv=3, scoring='r2', random_state=25)
random_search.fit(X_train_scaled, y_train.values.ravel())

# Best model
#best_model_scaled = grid_search_scaled.best_estimator_
best_model_scaled = random_search.best_estimator_

print("making predictions")
# Making predictions
y_train_pred_scaled = best_model_scaled.predict(X_train_scaled)
y_test_pred_scaled = best_model_scaled.predict(X_test_scaled)

print("Calculating metrics")
# Calculating metrics
r2_train_scaled = r2_score(y_train, y_train_pred_scaled)
mse_train_scaled = mean_squared_error(y_train, y_train_pred_scaled)
mape_train_scaled = mean_absolute_percentage_error(y_train, y_train_pred_scaled)

r2_test_scaled = r2_score(y_test, y_test_pred_scaled)
mse_test_scaled = mean_squared_error(y_test, y_test_pred_scaled)
mape_test_scaled = mean_absolute_percentage_error(y_test, y_test_pred_scaled)

# Storing metrics in a DataFrame
metrics_scaled = {
    'R2 (Train)': [r2_train_scaled],
    'MSE (Train)': [mse_train_scaled],
    'MAPE (Train)': [mape_train_scaled],
    'R2 (Test)': [r2_test_scaled],
    'MSE (Test)': [mse_test_scaled],
    'MAPE (Test)': [mape_test_scaled],
    'Best Parameters': [random_search.best_params_]
}

metrics_df_scaled = pd.DataFrame(metrics_scaled)
metrics_df_scaled

#import ace_tools as tools; tools.display_dataframe_to_user(name="SVR Model Metrics with Standard Scaling", dataframe=metrics_df_scaled)
# Out:
# Grid search
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# making predictions
# Calculating metrics
# CPU times: user 5min 23s, sys: 187 ms, total: 5min 24s
# Wall time: 5min 22s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)  \
# 0    0.241423      0.43101      2.195015   0.219002    0.435089     2.937845
#
#                                      Best Parameters
# 0  {'kernel': 'linear', 'gamma': 'auto', 'epsilon...

# %% [markdown]
# media boring, matriz x todo menos vector objetivo

# %%
# %%time
X = df_means.drop(['boring'], axis=1)
y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Simplified grid search parameters
param_grid_simplified = {
    'kernel': ['linear'],
    'C': [1],
    'gamma': ['auto'],
    'epsilon': [0.1]
}

# Initialize the SVR model
svr = SVR()

print("Grid search")
# Grid search with cross-validation
#grid_search_scaled = GridSearchCV(svr, param_grid_simplified, cv=3, scoring='r2')
#grid_search_scaled.fit(X_train_scaled, y_train.values.ravel())

random_search = RandomizedSearchCV(svr, param_distributions=param_grid_simplified, n_iter=10, cv=3, scoring='r2', random_state=25)
random_search.fit(X_train_scaled, y_train.values.ravel())

# Best model
#best_model_scaled = grid_search_scaled.best_estimator_
best_model_scaled = random_search.best_estimator_

print("making predictions")
# Making predictions
y_train_pred_scaled = best_model_scaled.predict(X_train_scaled)
y_test_pred_scaled = best_model_scaled.predict(X_test_scaled)

print("Calculating metrics")
# Calculating metrics
r2_train_scaled = r2_score(y_train, y_train_pred_scaled)
mse_train_scaled = mean_squared_error(y_train, y_train_pred_scaled)
mape_train_scaled = mean_absolute_percentage_error(y_train, y_train_pred_scaled)

r2_test_scaled = r2_score(y_test, y_test_pred_scaled)
mse_test_scaled = mean_squared_error(y_test, y_test_pred_scaled)
mape_test_scaled = mean_absolute_percentage_error(y_test, y_test_pred_scaled)

# Storing metrics in a DataFrame
metrics_scaled = {
    'R2 (Train)': [r2_train_scaled],
    'MSE (Train)': [mse_train_scaled],
    'MAPE (Train)': [mape_train_scaled],
    'R2 (Test)': [r2_test_scaled],
    'MSE (Test)': [mse_test_scaled],
    'MAPE (Test)': [mape_test_scaled],
    'Best Parameters': [random_search.best_params_]
}

metrics_df_scaled = pd.DataFrame(metrics_scaled)
metrics_df_scaled

#import ace_tools as tools; tools.display_dataframe_to_user(name="SVR Model Metrics with Standard Scaling", dataframe=metrics_df_scaled)
# Out:
# Grid search
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# making predictions
# Calculating metrics
# CPU times: user 4min 33s, sys: 164 ms, total: 4min 33s
# Wall time: 4min 32s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)  \
# 0    0.990331     0.005494      0.626182   0.990196    0.005462     0.665219
#
#                                      Best Parameters
# 0  {'kernel': 'linear', 'gamma': 'auto', 'epsilon...

# %% [markdown]
# ### 2.3 SVR con df mediana, y= beautiful

# %%
# %%time
X = df_medians.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_medians[['beautiful']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Simplified grid search parameters
param_grid_simplified = {
    'kernel': ['linear'],
    'C': [1],
    'gamma': ['auto'],
    'epsilon': [0.1]
}

# Initialize the SVR model
svr = SVR()

print("Grid search")
# Grid search with cross-validation
#grid_search_scaled = GridSearchCV(svr, param_grid_simplified, cv=3, scoring='r2')
#grid_search_scaled.fit(X_train_scaled, y_train.values.ravel())

random_search = RandomizedSearchCV(svr, param_distributions=param_grid_simplified, n_iter=10, cv=3, scoring='r2', random_state=25)
random_search.fit(X_train_scaled, y_train.values.ravel())

# Best model
#best_model_scaled = grid_search_scaled.best_estimator_
best_model_scaled = random_search.best_estimator_

print("making predictions")
# Making predictions
y_train_pred_scaled = best_model_scaled.predict(X_train_scaled)
y_test_pred_scaled = best_model_scaled.predict(X_test_scaled)

print("Calculating metrics")
# Calculating metrics
r2_train_scaled = r2_score(y_train, y_train_pred_scaled)
mse_train_scaled = mean_squared_error(y_train, y_train_pred_scaled)
mape_train_scaled = mean_absolute_percentage_error(y_train, y_train_pred_scaled)

r2_test_scaled = r2_score(y_test, y_test_pred_scaled)
mse_test_scaled = mean_squared_error(y_test, y_test_pred_scaled)
mape_test_scaled = mean_absolute_percentage_error(y_test, y_test_pred_scaled)

# Storing metrics in a DataFrame
metrics_scaled = {
    'R2 (Train)': [r2_train_scaled],
    'MSE (Train)': [mse_train_scaled],
    'MAPE (Train)': [mape_train_scaled],
    'R2 (Test)': [r2_test_scaled],
    'MSE (Test)': [mse_test_scaled],
    'MAPE (Test)': [mape_test_scaled],
    'Best Parameters': [random_search.best_params_]
}

metrics_df_scaled = pd.DataFrame(metrics_scaled)
metrics_df_scaled

#import ace_tools as tools; tools.display_dataframe_to_user(name="SVR Model Metrics with Standard Scaling", dataframe=metrics_df_scaled)
# Out:
# Grid search
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# making predictions
# Calculating metrics
# CPU times: user 4min 59s, sys: 178 ms, total: 4min 59s
# Wall time: 4min 58s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)  \
# 0    0.084712     0.586365       2.26202   0.073011    0.591206     2.239065
#
#                                      Best Parameters
# 0  {'kernel': 'linear', 'gamma': 'auto', 'epsilon...

# %% [markdown]
# X full

# %%
# %%time
X = df_medians.drop(['beautiful'], axis=1)
y = df_medians[['beautiful']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Simplified grid search parameters
param_grid_simplified = {
    'kernel': ['linear'],
    'C': [1],
    'gamma': ['auto'],
    'epsilon': [0.1]
}

# Initialize the SVR model
svr = SVR()

print("Grid search")
# Grid search with cross-validation
#grid_search_scaled = GridSearchCV(svr, param_grid_simplified, cv=3, scoring='r2')
#grid_search_scaled.fit(X_train_scaled, y_train.values.ravel())

random_search = RandomizedSearchCV(svr, param_distributions=param_grid_simplified, n_iter=10, cv=3, scoring='r2', random_state=25)
random_search.fit(X_train_scaled, y_train.values.ravel())

# Best model
#best_model_scaled = grid_search_scaled.best_estimator_
best_model_scaled = random_search.best_estimator_

print("making predictions")
# Making predictions
y_train_pred_scaled = best_model_scaled.predict(X_train_scaled)
y_test_pred_scaled = best_model_scaled.predict(X_test_scaled)

print("Calculating metrics")
# Calculating metrics
r2_train_scaled = r2_score(y_train, y_train_pred_scaled)
mse_train_scaled = mean_squared_error(y_train, y_train_pred_scaled)
mape_train_scaled = mean_absolute_percentage_error(y_train, y_train_pred_scaled)

r2_test_scaled = r2_score(y_test, y_test_pred_scaled)
mse_test_scaled = mean_squared_error(y_test, y_test_pred_scaled)
mape_test_scaled = mean_absolute_percentage_error(y_test, y_test_pred_scaled)

# Storing metrics in a DataFrame
metrics_scaled = {
    'R2 (Train)': [r2_train_scaled],
    'MSE (Train)': [mse_train_scaled],
    'MAPE (Train)': [mape_train_scaled],
    'R2 (Test)': [r2_test_scaled],
    'MSE (Test)': [mse_test_scaled],
    'MAPE (Test)': [mape_test_scaled],
    'Best Parameters': [random_search.best_params_]
}

metrics_df_scaled = pd.DataFrame(metrics_scaled)
metrics_df_scaled

#import ace_tools as tools; tools.display_dataframe_to_user(name="SVR Model Metrics with Standard Scaling", dataframe=metrics_df_scaled)
# Out:
# Grid search
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# making predictions
# Calculating metrics
# CPU times: user 8min 52s, sys: 391 ms, total: 8min 52s
# Wall time: 8min 50s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)  \
# 0    0.970961     0.018603      1.077149   0.969233    0.019622     0.886234
#
#                                      Best Parameters
# 0  {'kernel': 'linear', 'gamma': 'auto', 'epsilon...

# %% [markdown]
# ### 2.4 SVR con df mediana, y= boring

# %%
# %%time
X = df_medians.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_medians[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Simplified grid search parameters
param_grid_simplified = {
    'kernel': ['linear'],
    'C': [1],
    'gamma': ['auto'],
    'epsilon': [0.1]
}

# Initialize the SVR model
svr = SVR()

print("Grid search")
# Grid search with cross-validation
#grid_search_scaled = GridSearchCV(svr, param_grid_simplified, cv=3, scoring='r2')
#grid_search_scaled.fit(X_train_scaled, y_train.values.ravel())

random_search = RandomizedSearchCV(svr, param_distributions=param_grid_simplified, n_iter=10, cv=3, scoring='r2', random_state=25)
random_search.fit(X_train_scaled, y_train.values.ravel())

# Best model
#best_model_scaled = grid_search_scaled.best_estimator_
best_model_scaled = random_search.best_estimator_

print("making predictions")
# Making predictions
y_train_pred_scaled = best_model_scaled.predict(X_train_scaled)
y_test_pred_scaled = best_model_scaled.predict(X_test_scaled)

print("Calculating metrics")
# Calculating metrics
r2_train_scaled = r2_score(y_train, y_train_pred_scaled)
mse_train_scaled = mean_squared_error(y_train, y_train_pred_scaled)
mape_train_scaled = mean_absolute_percentage_error(y_train, y_train_pred_scaled)

r2_test_scaled = r2_score(y_test, y_test_pred_scaled)
mse_test_scaled = mean_squared_error(y_test, y_test_pred_scaled)
mape_test_scaled = mean_absolute_percentage_error(y_test, y_test_pred_scaled)

# Storing metrics in a DataFrame
metrics_scaled = {
    'R2 (Train)': [r2_train_scaled],
    'MSE (Train)': [mse_train_scaled],
    'MAPE (Train)': [mape_train_scaled],
    'R2 (Test)': [r2_test_scaled],
    'MSE (Test)': [mse_test_scaled],
    'MAPE (Test)': [mape_test_scaled],
    'Best Parameters': [random_search.best_params_]
}

metrics_df_scaled = pd.DataFrame(metrics_scaled)
metrics_df_scaled

#import ace_tools as tools; tools.display_dataframe_to_user(name="SVR Model Metrics with Standard Scaling", dataframe=metrics_df_scaled)
# Out:
# Grid search
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# making predictions
# Calculating metrics
# CPU times: user 5min 4s, sys: 216 ms, total: 5min 4s
# Wall time: 5min 3s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)  \
# 0    0.216287     0.512842      2.379681   0.187049    0.522004     1.902147
#
#                                      Best Parameters
# 0  {'kernel': 'linear', 'gamma': 'auto', 'epsilon...

# %% [markdown]
# x full

# %%
# %%time
X = df_medians.drop(['boring'], axis=1)
y = df_medians[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Simplified grid search parameters
param_grid_simplified = {
    'kernel': ['linear'],
    'C': [1],
    'gamma': ['auto'],
    'epsilon': [0.1]
}

# Initialize the SVR model
svr = SVR()

print("Grid search")
# Grid search with cross-validation
#grid_search_scaled = GridSearchCV(svr, param_grid_simplified, cv=3, scoring='r2')
#grid_search_scaled.fit(X_train_scaled, y_train.values.ravel())

random_search = RandomizedSearchCV(svr, param_distributions=param_grid_simplified, n_iter=10, cv=3, scoring='r2', random_state=25)
random_search.fit(X_train_scaled, y_train.values.ravel())

# Best model
#best_model_scaled = grid_search_scaled.best_estimator_
best_model_scaled = random_search.best_estimator_

print("making predictions")
# Making predictions
y_train_pred_scaled = best_model_scaled.predict(X_train_scaled)
y_test_pred_scaled = best_model_scaled.predict(X_test_scaled)

print("Calculating metrics")
# Calculating metrics
r2_train_scaled = r2_score(y_train, y_train_pred_scaled)
mse_train_scaled = mean_squared_error(y_train, y_train_pred_scaled)
mape_train_scaled = mean_absolute_percentage_error(y_train, y_train_pred_scaled)

r2_test_scaled = r2_score(y_test, y_test_pred_scaled)
mse_test_scaled = mean_squared_error(y_test, y_test_pred_scaled)
mape_test_scaled = mean_absolute_percentage_error(y_test, y_test_pred_scaled)

# Storing metrics in a DataFrame
metrics_scaled = {
    'R2 (Train)': [r2_train_scaled],
    'MSE (Train)': [mse_train_scaled],
    'MAPE (Train)': [mape_train_scaled],
    'R2 (Test)': [r2_test_scaled],
    'MSE (Test)': [mse_test_scaled],
    'MAPE (Test)': [mape_test_scaled],
    'Best Parameters': [random_search.best_params_]
}

metrics_df_scaled = pd.DataFrame(metrics_scaled)
metrics_df_scaled

#import ace_tools as tools; tools.display_dataframe_to_user(name="SVR Model Metrics with Standard Scaling", dataframe=metrics_df_scaled)
# Out:
# Grid search
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=10. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# making predictions
# Calculating metrics
# CPU times: user 9min 38s, sys: 448 ms, total: 9min 39s
# Wall time: 9min 36s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)  \
# 0     0.92983     0.045917       1.51809   0.930068    0.044904     1.399212
#
#                                      Best Parameters
# 0  {'kernel': 'linear', 'gamma': 'auto', 'epsilon...

# %% [markdown]
# ## 3.MLP

# %% [markdown]
# ### 3.1 MLP con df media, y= beautiful

# %%
# %%time
X = df_means.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_means[['beautiful']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# Step 1: Scale the Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Define the MLP Model
mlp = MLPRegressor(hidden_layer_sizes=(50,), activation='relu',
                   solver='adam', alpha=0.001,
                   early_stopping=True, validation_fraction=0.1,
                   n_iter_no_change=10,
                   max_iter=1000, random_state=25)

# Step 3: Train the Model
mlp.fit(X_train_scaled, y_train.values.ravel())

# Step 4: Evaluate the Model
y_train_pred = mlp.predict(X_train_scaled)
y_test_pred = mlp.predict(X_test_scaled)

# Calculate metrics for training data
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
mape_train = mean_absolute_percentage_error(y_train, y_train_pred)

# Calculate metrics for testing data
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# Print or display the metrics
metrics = {
    'R2 (Train)': r2_train,
    'MSE (Train)': mse_train,
    'MAPE (Train)': mape_train,
    'R2 (Test)': r2_test,
    'MSE (Test)': mse_test,
    'MAPE (Test)': mape_test
}

metrics_df = pd.DataFrame([metrics])
metrics_df
# Out:
# CPU times: user 5.18 s, sys: 9.3 s, total: 14.5 s
# Wall time: 2.12 s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)
# 0    0.140466     0.491544      2.167723   0.076599    0.516033     2.499319

# %% [markdown]
# media beautiful, matriz x todo menos vector objetivo

# %%
# %%time
X = df_means.drop(['beautiful'], axis=1)
y = df_means[['beautiful']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# Step 1: Scale the Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Define the MLP Model
mlp = MLPRegressor(hidden_layer_sizes=(50,), activation='relu',
                   solver='adam', alpha=0.001,
                   early_stopping=True, validation_fraction=0.1,
                   n_iter_no_change=10,
                   max_iter=1000, random_state=25)

# Step 3: Train the Model
mlp.fit(X_train_scaled, y_train.values.ravel())

# Step 4: Evaluate the Model
y_train_pred = mlp.predict(X_train_scaled)
y_test_pred = mlp.predict(X_test_scaled)

# Calculate metrics for training data
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
mape_train = mean_absolute_percentage_error(y_train, y_train_pred)

# Calculate metrics for testing data
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# Print or display the metrics
metrics = {
    'R2 (Train)': r2_train,
    'MSE (Train)': mse_train,
    'MAPE (Train)': mape_train,
    'R2 (Test)': r2_test,
    'MSE (Test)': mse_test,
    'MAPE (Test)': mape_test
}

metrics_df = pd.DataFrame([metrics])
metrics_df
# Out:
# CPU times: user 17 s, sys: 27.2 s, total: 44.2 s
# Wall time: 5.67 s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)
# 0    0.994604     0.003086      0.436805   0.991849    0.004555     0.473586

# %% [markdown]
# ### 3.2 MLP con df media, y= boring

# %%
# %%time
X = df_means.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# Step 1: Scale the Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Define the MLP Model
mlp = MLPRegressor(hidden_layer_sizes=(50,), activation='relu',
                   solver='adam', alpha=0.001,
                   early_stopping=True, validation_fraction=0.1,
                   n_iter_no_change=10,
                   max_iter=1000, random_state=25)

# Step 3: Train the Model
mlp.fit(X_train_scaled, y_train.values.ravel())

# Step 4: Evaluate the Model
y_train_pred = mlp.predict(X_train_scaled)
y_test_pred = mlp.predict(X_test_scaled)

# Calculate metrics for training data
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
mape_train = mean_absolute_percentage_error(y_train, y_train_pred)

# Calculate metrics for testing data
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# Print or display the metrics
metrics = {
    'R2 (Train)': r2_train,
    'MSE (Train)': mse_train,
    'MAPE (Train)': mape_train,
    'R2 (Test)': r2_test,
    'MSE (Test)': mse_test,
    'MAPE (Test)': mape_test
}

metrics_df = pd.DataFrame([metrics])
metrics_df
# Out:
# CPU times: user 5.68 s, sys: 9.4 s, total: 15.1 s
# Wall time: 1.94 s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)
# 0    0.301948     0.396621      2.186733   0.210844    0.439634     3.620486

# %% [markdown]
# media boring, matriz x todo menos vector objetivo

# %%
# %%time
X = df_means.drop(['boring'], axis=1)
y = df_means[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# Step 1: Scale the Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Define the MLP Model
mlp = MLPRegressor(hidden_layer_sizes=(50,), activation='relu',
                   solver='adam', alpha=0.001,
                   early_stopping=True, validation_fraction=0.1,
                   n_iter_no_change=10,
                   max_iter=1000, random_state=25)

# Step 3: Train the Model
mlp.fit(X_train_scaled, y_train.values.ravel())

# Step 4: Evaluate the Model
y_train_pred = mlp.predict(X_train_scaled)
y_test_pred = mlp.predict(X_test_scaled)

# Calculate metrics for training data
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
mape_train = mean_absolute_percentage_error(y_train, y_train_pred)

# Calculate metrics for testing data
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# Print or display the metrics
metrics = {
    'R2 (Train)': r2_train,
    'MSE (Train)': mse_train,
    'MAPE (Train)': mape_train,
    'R2 (Test)': r2_test,
    'MSE (Test)': mse_test,
    'MAPE (Test)': mape_test
}

metrics_df = pd.DataFrame([metrics])
metrics_df
# Out:
# CPU times: user 18.7 s, sys: 38.4 s, total: 57.1 s
# Wall time: 8.94 s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)
# 0    0.990856     0.005195      0.584625   0.987188    0.007137      0.64001

# %% [markdown]
# ### 3.3 MLP con df mediana, y= beautiful

# %%
# %%time
X = df_medians.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_medians[['beautiful']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# Step 1: Scale the Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Define the MLP Model
mlp = MLPRegressor(hidden_layer_sizes=(50,), activation='relu',
                   solver='adam', alpha=0.001,
                   early_stopping=True, validation_fraction=0.1,
                   n_iter_no_change=10,
                   max_iter=1000, random_state=25)

# Step 3: Train the Model
mlp.fit(X_train_scaled, y_train.values.ravel())

# Step 4: Evaluate the Model
y_train_pred = mlp.predict(X_train_scaled)
y_test_pred = mlp.predict(X_test_scaled)

# Calculate metrics for training data
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
mape_train = mean_absolute_percentage_error(y_train, y_train_pred)

# Calculate metrics for testing data
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# Print or display the metrics
metrics = {
    'R2 (Train)': r2_train,
    'MSE (Train)': mse_train,
    'MAPE (Train)': mape_train,
    'R2 (Test)': r2_test,
    'MSE (Test)': mse_test,
    'MAPE (Test)': mape_test
}

metrics_df = pd.DataFrame([metrics])
metrics_df
# Out:
# CPU times: user 4.19 s, sys: 7.28 s, total: 11.5 s
# Wall time: 1.5 s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)
# 0    0.134875     0.554229      2.163657   0.062002    0.598227     2.015932

# %% [markdown]
# mediana beautiful, matriz x todo menos vector objetivo

# %%
# %%time
X = df_medians.drop(['beautiful'], axis=1)
y = df_medians[['beautiful']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# Step 1: Scale the Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Define the MLP Model
mlp = MLPRegressor(hidden_layer_sizes=(50,), activation='relu',
                   solver='adam', alpha=0.001,
                   early_stopping=True, validation_fraction=0.1,
                   n_iter_no_change=10,
                   max_iter=1000, random_state=25)

# Step 3: Train the Model
mlp.fit(X_train_scaled, y_train.values.ravel())

# Step 4: Evaluate the Model
y_train_pred = mlp.predict(X_train_scaled)
y_test_pred = mlp.predict(X_test_scaled)

# Calculate metrics for training data
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
mape_train = mean_absolute_percentage_error(y_train, y_train_pred)

# Calculate metrics for testing data
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# Print or display the metrics
metrics = {
    'R2 (Train)': r2_train,
    'MSE (Train)': mse_train,
    'MAPE (Train)': mape_train,
    'R2 (Test)': r2_test,
    'MSE (Test)': mse_test,
    'MAPE (Test)': mape_test
}

metrics_df = pd.DataFrame([metrics])
metrics_df
# Out:
# CPU times: user 11 s, sys: 18.7 s, total: 29.7 s
# Wall time: 3.89 s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)
# 0    0.972859     0.017387      0.991538   0.963007    0.023593     1.001058

# %% [markdown]
# ### 3.4 MLP con df mediana, y= boring

# %%
# %%time
X = df_medians.drop(['beautiful', 'boring', 'depressing', 'lively', 'safe', 'wealthy'], axis=1)
y = df_medians[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# Step 1: Scale the Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Define the MLP Model
mlp = MLPRegressor(hidden_layer_sizes=(50,), activation='relu',
                   solver='adam', alpha=0.001,
                   early_stopping=True, validation_fraction=0.1,
                   n_iter_no_change=10,
                   max_iter=1000, random_state=25)

# Step 3: Train the Model
mlp.fit(X_train_scaled, y_train.values.ravel())

# Step 4: Evaluate the Model
y_train_pred = mlp.predict(X_train_scaled)
y_test_pred = mlp.predict(X_test_scaled)

# Calculate metrics for training data
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
mape_train = mean_absolute_percentage_error(y_train, y_train_pred)

# Calculate metrics for testing data
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# Print or display the metrics
metrics = {
    'R2 (Train)': r2_train,
    'MSE (Train)': mse_train,
    'MAPE (Train)': mape_train,
    'R2 (Test)': r2_test,
    'MSE (Test)': mse_test,
    'MAPE (Test)': mape_test
}

metrics_df = pd.DataFrame([metrics])
metrics_df
# Out:
# CPU times: user 8.55 s, sys: 13.8 s, total: 22.4 s
# Wall time: 2.86 s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)
# 0    0.295227     0.461186      2.660396   0.177673    0.528023     2.471492

# %% [markdown]
# mediana boring, matriz x todo menos vector objetivo

# %%
# %%time
X = df_medians.drop(['boring'], axis=1)
y = df_medians[['boring']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=25)

# Step 1: Scale the Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Step 2: Define the MLP Model
mlp = MLPRegressor(hidden_layer_sizes=(50,), activation='relu',
                   solver='adam', alpha=0.001,
                   early_stopping=True, validation_fraction=0.1,
                   n_iter_no_change=10,
                   max_iter=1000, random_state=25)

# Step 3: Train the Model
mlp.fit(X_train_scaled, y_train.values.ravel())

# Step 4: Evaluate the Model
y_train_pred = mlp.predict(X_train_scaled)
y_test_pred = mlp.predict(X_test_scaled)

# Calculate metrics for training data
r2_train = r2_score(y_train, y_train_pred)
mse_train = mean_squared_error(y_train, y_train_pred)
mape_train = mean_absolute_percentage_error(y_train, y_train_pred)

# Calculate metrics for testing data
r2_test = r2_score(y_test, y_test_pred)
mse_test = mean_squared_error(y_test, y_test_pred)
mape_test = mean_absolute_percentage_error(y_test, y_test_pred)

# Print or display the metrics
metrics = {
    'R2 (Train)': r2_train,
    'MSE (Train)': mse_train,
    'MAPE (Train)': mape_train,
    'R2 (Test)': r2_test,
    'MSE (Test)': mse_test,
    'MAPE (Test)': mape_test
}

metrics_df = pd.DataFrame([metrics])
metrics_df
# Out:
# CPU times: user 15.3 s, sys: 27.7 s, total: 43 s
# Wall time: 6.39 s
#    R2 (Train)  MSE (Train)  MAPE (Train)  R2 (Test)  MSE (Test)  MAPE (Test)
# 0    0.936824     0.041341       1.54345   0.922052    0.050051     1.613023
